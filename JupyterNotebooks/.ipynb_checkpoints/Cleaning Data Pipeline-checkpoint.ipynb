# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

#for importing files
import glob, os
import matplotlib.pyplot as plt
# %matplotlib inline


#Library for hull calculation
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
from matplotlib.path import Path
from scipy.spatial import distance

# %% [markdown]
# ## Helper Methods

# %%
def SecsToGameTime(time):
    mins=(int(time)/60)
    secs=int(time)%60
    print (str(mins)+":"+str(secs))

# %%
def GameTimetoSeconds(time):
    mins, secs = time.split(":")
    timeSecs = int(mins)*60+int(secs)
    print(timeSecs)
    return timeSecs

# %% [markdown]
# #### Hull Calculation Helper Method

# %%
def getHull(moments, teamID):
    points = []
    
    if(moments[5][1][0] == teamID):
        for positions in moments[5][1:6]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    else:
        for positions in moments[5][6:11]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    
    np_points = np.asarray(points)
    np_points
    hull = ConvexHull(np_points)
    
    return hull,np_points

# %%
def distFromCentroid(hull, x,y):
        cx = np.mean(hull.points[hull.vertices,0])
        cy = np.mean(hull.points[hull.vertices,1])
        return ((x-cx)^2+(y-cy)^2)^.5

# %%
def isInHull(hull,np_points,x,y):
    #point in hull?
    hull_path = Path( np_points[hull.vertices] )
    isInPath = hull_path.contains_point((x,y))
    return (isInPath == True)

# %% [markdown]
# ### Given the game time (12:00) and eventNumber from the Play-by-play data for a recorded event, this method returns the correct eventNumber from the SportsVU data since they actually dont matchup.  This method converts the gametime into seconds (720s = 12:00) which is formatted in SportsVU.  It traverses up and down events until the gametime is within a selected eventNumber.

# %%
def findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, approxEventNumPBP):
    print("Finding correctSportVU eventNum gameid:"+rawSportVUData['gameid'])

    found = False;
    moments = None
    #convert gametimePBP (12:00) to seconds (720)
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    while (found == False):
        moments = MomentsfromEventNum(rawSportVUData, approxEventNumPBP)
        quarterSportVU = int(moments[0][0])
        print("PBP quareter:"+str(quarterPBP)+"quartersportVU :"+str(quarterSportVU))
        print("PBP gameclock:"+str(gameInSeconds)+" SportsVU moment clock:"+str(moments[0][2]))
        
        #check whether this EventNum moment is the correct time frame of the play from Play-by-play
        if(quarterPBP < quarterSportVU):
            approxEventNumPBP -= 1
        elif(quarterPBP > quarterSportVU):    
            approxEventNumPBP  += 1
        elif(int(moments[0][2]) > gameInSeconds and int(moments[len(moments)-1][2]) < gameInSeconds):
            found=True
        elif(moments[0][2] < gameInSeconds):
            approxEventNumPBP -= 1
        elif(moments[len(moments)-1][2] > gameInSeconds):
        # look ahead 1 event 
            approxEventNumPBP += 1
        else:
            return "error"
    print("extracted event num "+ str(approxEventNumPBP))
    return approxEventNumPBP

# %%
def MomentsfromEventNum(eventsData, eventNum):
    return eventsData['events'][eventNum]["moments"]

# %% [markdown]
# ## Identify Moment of CATCH
#
# 1.  //sort events moment data from end time to beginning (reverse order)
# timeballReceived, locationballReceived = getReceive (recieverID, List[Moments])
#
# Each moment is taken every .25s, so the FIRST 8 moments (8 *.25 = 2 seconds) when the receiverID and ball are within (dist <= 1 ft), is when the ball was the moment before the ball was released.
#
# reset numCount = 0;
#
# Starting from this time, continue iterating through moments. If dist from receiver and ball >=1 ft, then this is time the ball was caught.
#
# ***separate calculation to check when the ball dist less than 1 ft for another teammate to determine if it was a pass in a certain amount of time (counted numCount)****
#
# 2.  Find "latest" instance when   distFrom ( Moment.Positions[0].x,Moment.Position[0].y , Moment.Position[ ??=playerID ].x , Moment.Position[ ??=playerID].y) <= 1ft )
#
#    return the timemilis ,  position[0].x , position[0].y

# %%
def getCatchEventDetails(receiverID, passerID, gametimePBP, moments):
    print ("Getting Catch Event Details")
    momentsReversed = moments[::-1]

    index=0
    found = False
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    print("num of moments: "+str(len(momentsReversed)))
    while (found == False):
        if(int(momentsReversed[index][2]) >=  gameInSeconds):
            found=True
        elif(int(momentsReversed[index][2]< gameInSeconds)):
            index += 1
        else:
            return "ERROR"
    
    print("starting at time: "+ str(momentsReversed[index][2]))
    
    #Found the index of the approx start of the event
    numCounts=0
    for i in range(index,len(momentsReversed)):
        if numCounts >= 3:
            timeBallReleased = momentsReversed[i][2]
            indexBallReleased = i
            break
        else:
            ball = momentsReversed[i][5][0]
            for positions in momentsReversed[i][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("receiver holding ball: " + str( momentsReversed[i][3]))
                numCounts += 1
                
    #count when ball is caught
    numCounts=0
    for j in range(indexBallReleased, len(momentsReversed)):
        if numCounts >= 3:
            timeBallCaught = momentsReversed[j][2]
            indexBallCaught = j
            break
        else:
            ball = momentsReversed[j][5][0]
            for positions in momentsReversed[j][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist >= 2:
                print("receiver just caught ball: " + str(momentsReversed[j][3])+" "+str(j))
                numCounts += 1
                
    #count when ball is passed
    numCounts=0
    for k in range(indexBallCaught, len(momentsReversed)):
        if numCounts >= 2:
            timeBallPassed = momentsReversed[k][2]
            indexBallPassed = k
            break
        else:
            print("aga")
            ball = momentsReversed[k][5][0]
            for positions in momentsReversed[k][5]:
                if positions[1] == passerID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("passer just passed ball: " +str(momentsReversed[k][3]))
                numCounts += 1
                
    SecsToGameTime(timeBallPassed)
    SecsToGameTime(timeBallCaught)
    SecsToGameTime(timeBallReleased)      
    return timeBallReleased, indexBallReleased, timeBallCaught, indexBallCaught, timeBallPassed, indexBallPassed

# %% [markdown]
# ### Extracts Assists, Bad Passes, Alley Oops from csvs in current directory and saves them into separate csv files

# %%
AST_df = pd.DataFrame()
BadPass_df = pd.DataFrame()
AlleyOop_df = pd.DataFrame()
curPath = os.getcwd()
print curPath
os.chdir(curPath)
for pbpFile in glob.glob("*.csv"):
    print(pbpFile)
    #read file as df
    events_df = pd.read_csv(pbpFile)
    ASTList = events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("AST", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("AST", na = False )  ) ]
    BadPassList= events_df[( events_df['VISITORDESCRIPTION'].str.contains("Bad", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Bad", na = False )  ) ]
    AlleyOopList= events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("Alley", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Alley", na = False )  ) ]
    AST_df = AST_df.append(ASTList)
    BadPass_df = BadPass_df.append(BadPassList)
    AlleyOop_df = AlleyOop_df.append(AlleyOopList)
    
AST_df.to_csv("AST_Parsed.csv", sep='\t')
BadPass_df.to_csv("BadPass_Parsed.csv", sep='\t')
AlleyOop_df.to_csv("AlleyOop_Parsed.csv", sep='\t')
# Out:
# D:\DataMining-NBA-Repo\JupyterNotebooks\pbp-csv
# 0021500001.csv
# 0021500002.csv
# 0021500003.csv
# 0021500004.csv

# %% [markdown]
# ## AST_df  assists data frame has time and event num of all assists....

# %%
AST_df
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 5    21500001         5             1                  80       1
# 6    21500001         6             1                  80       1
# 7    21500001         7             1                 101       1
# 12   21500001        13             1                 105       1
# 28   21500001        33             1                   7       1
# 40   21500001        47             1                   1       1
# 46   21500001        55             1                  63       1
# 49   21500001        58             1                   1       1
# 67   21500001        77             1                 101       1
# 70   21500001        81             1                  98       1
# 75   21500001        86             1                  43       1
# 92   21500001       105             1                  42       1
# 97   21500001       110             1                   1       1
# 119  21500001       132             1                   1       2
# 121  21500001       137             1                   1       2
# 134  21500001       150             1                   1       2
# 154  21500001       172             1                   1       2
# 161  21500001       180             1                  41       2
# 176  21500001       197             1                   1       2
# 190  21500001       214             1                   1       2
# 206  21500001       232             1                  50       2
# 240  21500001       269             1                  79       3
# 248  21500001       282             1                  79       3
# 260  21500001       294             1                   1       3
# 261  21500001       295             1                  42       3
# 265  21500001       301             1                   1       3
# 268  21500001       304             1                  63       3
# 279  21500001       317             1                   7       3
# 282  21500001       321             1                   1       3
# 284  21500001       324             1                  44       3
# ..        ...       ...           ...                 ...     ...
# 47   21500004        52             1                   5       1
# 65   21500004        71             1                  41       1
# 66   21500004        72             1                  46       1
# 67   21500004        73             1                   1       1
# 72   21500004        78             1                  46       1
# 78   21500004        84             1                   1       1
# 81   21500004        87             1                   1       1
# 82   21500004        89             1                   1       1
# 105  21500004       123             1                   1       1
# 120  21500004       142             1                   1       2
# 128  21500004       150             1                   1       2
# 148  21500004       174             1                  98       2
# 155  21500004       182             1                  41       2
# 169  21500004       198             1                   3       2
# 171  21500004       200             1                  98       2
# 172  21500004       201             1                   1       2
# 190  21500004       219             1                  79       2
# 202  21500004       233             1                  81       2
# 203  21500004       234             1                   1       2
# 205  21500004       236             1                  46       2
# 267  21500004       313             1                   1       3
# 310  21500004       360             1                 103       3
# 321  21500004       375             1                  42       3
# 322  21500004       376             1                  58       3
# 336  21500004       391             1                   1       3
# 371  21500004       432             1                  57       4
# 380  21500004       442             1                  79       4
# 451  21500004       527             1                   3       4
# 458  21500004       534             1                   1       4
# 463  21500004       542             1                  50       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 5        8:13 PM        11:21
# 6        8:13 PM        11:00
# 7        8:14 PM        10:44
# 12       8:14 PM        10:01
# 28       8:17 PM         8:11
# 40       8:22 PM         6:48
# 46       8:23 PM         6:30
# 49       8:24 PM         5:57
# 67       8:26 PM         4:23
# 70       8:27 PM         4:13
# 75       8:27 PM         3:33
# 92       8:32 PM         1:47
# 97       8:33 PM         0:32
# 119      8:40 PM        10:31
# 121      8:43 PM        10:20
# 134      8:45 PM         8:48
# 154      8:48 PM         7:06
# 161      8:49 PM         6:05
# 176      8:54 PM         4:35
# 190      8:57 PM         2:50
# 206      9:02 PM         0:55
# 240      9:24 PM         8:37
# 248      9:28 PM         7:42
# 260      9:31 PM         5:55
# 261      9:31 PM         5:39
# 265      9:33 PM         5:13
# 268      9:34 PM         4:50
# 279      9:35 PM         4:10
# 282      9:36 PM         3:32
# 284      9:37 PM         2:52
# ..           ...          ...
# 47       7:26 PM         6:12
# 65       7:28 PM         4:38
# 66       7:28 PM         4:33
# 67       7:28 PM         4:22
# 72       7:29 PM         3:47
# 78       7:30 PM         3:28
# 81       7:31 PM         2:51
# 82       7:31 PM         2:33
# 105      7:39 PM         0:33
# 120      7:44 PM        11:24
# 128      7:46 PM        10:28
# 148      7:48 PM         9:15
# 155      7:49 PM         8:33
# 169      7:54 PM         7:10
# 171      7:54 PM         6:46
# 172      7:55 PM         6:29
# 190      7:56 PM         5:02
# 202      8:02 PM         3:28
# 203      8:02 PM         3:11
# 205      8:02 PM         2:33
# 267      8:32 PM        10:21
# 310      8:40 PM         6:18
# 321      8:45 PM         4:50
# 322      8:45 PM         4:32
# 336      8:48 PM         3:04
# 371      8:58 PM        11:08
# 380      9:00 PM        10:17
# 451      9:17 PM         3:07
# 458      9:18 PM         2:19
# 463      9:22 PM         2:00
#
#                                        HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 5                                                  NaN                 NaN
# 6    Millsap 12' Step Back Jump Shot (2 PTS) (Korve...                 NaN
# 7                                                  NaN                 NaN
# 12   Millsap 12' Turnaround Fadeaway Bank Jump Shot...                 NaN
# 28                                                 NaN                 NaN
# 40                                                 NaN                 NaN
# 46                                                 NaN                 NaN
# 49                                                 NaN                 NaN
# 67                                                 NaN                 NaN
# 70   Schroder 1' Cutting Layup Shot (2 PTS) (Millsa...                 NaN
# 75                                                 NaN                 NaN
# 92   Schroder 2' Driving Layup (4 PTS) (Patterson 1...                 NaN
# 97   Patterson  3PT Jump Shot (3 PTS) (Schroder 1 AST)                 NaN
# 119  Horford 24' 3PT Jump Shot (3 PTS) (Schroder 2 ...                 NaN
# 121                                                NaN                 NaN
# 134                                                NaN                 NaN
# 154                                                NaN                 NaN
# 161  Teague 2' Running Layup (8 PTS) (Sefolosha 1 AST)                 NaN
# 176                                                NaN                 NaN
# 190                                                NaN                 NaN
# 206                                                NaN                 NaN
# 240                                                NaN                 NaN
# 248  Korver 20' Pullup Jump Shot (2 PTS) (Horford 2...                 NaN
# 260  Millsap 25' 3PT Jump Shot (13 PTS) (Teague 1 AST)                 NaN
# 261                                                NaN                 NaN
# 265                                                NaN                 NaN
# 268                                                NaN                 NaN
# 279           Splitter  Dunk (4 PTS) (Sefolosha 2 AST)                 NaN
# 282  Schroder 25' 3PT Jump Shot (11 PTS) (Millsap 2...                 NaN
# 284  Millsap 2' Reverse Layup (15 PTS) (Sefolosha 3...                 NaN
# ..                                                 ...                 ...
# 47                                                 NaN                 NaN
# 65                                                 NaN                 NaN
# 66   Hezonja 27' 3PT Running Jump Shot (3 PTS) (Pay...                 NaN
# 67                                                 NaN                 NaN
# 72   Hezonja 7' Running Jump Shot (5 PTS) (Payton 2...                 NaN
# 78         Payton 21' Jump Shot (2 PTS) (Gordon 1 AST)                 NaN
# 81       Hezonja  3PT Jump Shot (8 PTS) (Payton 3 AST)                 NaN
# 82                                                 NaN                 NaN
# 105        Watson 18' Jump Shot (2 PTS) (Payton 4 AST)                 NaN
# 120                                                NaN                 NaN
# 128       Payton 19' Jump Shot (6 PTS) (Oladipo 2 AST)                 NaN
# 148  Oladipo 1' Cutting Layup Shot (4 PTS) (Harris ...                 NaN
# 155    Oladipo 2' Running Layup (6 PTS) (Harris 2 AST)                 NaN
# 169                                                NaN                 NaN
# 171                                                NaN                 NaN
# 172         Smith 20' Jump Shot (2 PTS) (Watson 1 AST)                 NaN
# 190                                                NaN                 NaN
# 202  Gordon 5' Pullup Bank Shot (6 PTS) (Payton 5 AST)                 NaN
# 203                                                NaN                 NaN
# 205                                                NaN                 NaN
# 267                                                NaN                 NaN
# 310  Harris 17' Running Pull-Up Jump Shot (11 PTS) ...                 NaN
# 321                                                NaN                 NaN
# 322  Vucevic 4' Turnaround Hook Shot (8 PTS) (Payto...                 NaN
# 336     Oladipo  3PT Jump Shot (11 PTS) (Harris 3 AST)                 NaN
# 371  Dedmon 7' Driving Hook Shot (4 PTS) (Hezonja 1...                 NaN
# 380                                                NaN                 NaN
# 451      Vucevic 8' Hook Shot (10 PTS) (Hezonja 2 AST)                 NaN
# 458  Hezonja 24' 3PT Jump Shot (11 PTS) (Vucevic 2 ...                 NaN
# 463     Harris 1' Running Dunk (15 PTS) (Payton 8 AST)                 NaN
#
#                                     VISITORDESCRIPTION  \
# 5    Marc Morris 13' Step Back Jump Shot (2 PTS) (D...
# 6                                                  NaN
# 7    Caldwell-Pope 9' Driving Floating Jump Shot (2...
# 12                                                 NaN
# 28             Drummond  Dunk (2 PTS) (Ilyasova 2 AST)
# 40   Ilyasova 24' 3PT Jump Shot (3 PTS) (Marc Morri...
# 46   Marc Morris 20' Fadeaway Jumper (7 PTS) (Jacks...
# 49   Caldwell-Pope 24' 3PT Jump Shot (5 PTS) (Jacks...
# 67   Jackson 9' Driving Floating Jump Shot (5 PTS) ...
# 70                                                 NaN
# 75   Drummond  Alley Oop Layup (4 PTS) (Jackson 3 AST)
# 92                                                 NaN
# 97                                                 NaN
# 119                                                NaN
# 121    Blake 24' 3PT Jump Shot (3 PTS) (Johnson 1 AST)
# 134    Johnson 24' 3PT Jump Shot (3 PTS) (Blake 1 AST)
# 154  Ilyasova 26' 3PT Jump Shot (6 PTS) (Johnson 2 ...
# 161                                                NaN
# 176  Marc Morris 25' 3PT Jump Shot (10 PTS) (Caldwe...
# 190  Caldwell-Pope 25' 3PT Jump Shot (8 PTS) (Jacks...
# 206  Caldwell-Pope  Running Dunk (10 PTS) (Drummond...
# 240  Caldwell-Pope 19' Pullup Jump Shot (12 PTS) (D...
# 248                                                NaN
# 260                                                NaN
# 261  Ilyasova 1' Driving Layup (11 PTS) (Jackson 5 ...
# 265  Caldwell-Pope 24' 3PT Jump Shot (19 PTS) (Marc...
# 268  Ilyasova 16' Fadeaway Jumper (13 PTS) (Marc Mo...
# 279                                                NaN
# 282                                                NaN
# 284                                                NaN
# ..                                                 ...
# 47            Beal 1' Layup (5 PTS) (Porter Jr. 2 AST)
# 65        Beal 1' Running Layup (7 PTS) (Gortat 2 AST)
# 66                                                 NaN
# 67   Gooden 24' 3PT Jump Shot (3 PTS) (Sessions 1 AST)
# 72                                                 NaN
# 78                                                 NaN
# 81                                                 NaN
# 82        Beal 21' Jump Shot (12 PTS) (Sessions 2 AST)
# 105                                                NaN
# 120            Neal 17' Jump Shot (2 PTS) (Nene 1 AST)
# 128                                                NaN
# 148                                                NaN
# 155                                                NaN
# 169           Gortat 3' Hook Shot (4 PTS) (Wall 3 AST)
# 171  Gortat 1' Cutting Layup Shot (6 PTS) (Porter J...
# 172                                                NaN
# 190     Neal 21' Pullup Jump Shot (6 PTS) (Wall 4 AST)
# 202                                                NaN
# 203  Humphries 21' Jump Shot (4 PTS) (Porter Jr. 4 ...
# 205  Humphries  3PT Running Jump Shot (7 PTS) (Wall...
# 267    Gortat 11' Jump Shot (8 PTS) (Porter Jr. 5 AST)
# 310                                                NaN
# 321        Beal 2' Driving Layup (17 PTS) (Wall 6 AST)
# 322                                                NaN
# 336                                                NaN
# 371                                                NaN
# 380  Wall 19' Pullup Jump Shot (12 PTS) (Gooden 1 AST)
# 451                                                NaN
# 458                                                NaN
# 463                                                NaN
#
#                ...             PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  \
# 5              ...                       Detroit               Pistons
# 6              ...                       Atlanta                 Hawks
# 7              ...                       Detroit               Pistons
# 12             ...                       Atlanta                 Hawks
# 28             ...                       Detroit               Pistons
# 40             ...                       Detroit               Pistons
# 46             ...                       Detroit               Pistons
# 49             ...                       Detroit               Pistons
# 67             ...                       Detroit               Pistons
# 70             ...                       Atlanta                 Hawks
# 75             ...                       Detroit               Pistons
# 92             ...                       Atlanta                 Hawks
# 97             ...                       Atlanta                 Hawks
# 119            ...                       Atlanta                 Hawks
# 121            ...                       Detroit               Pistons
# 134            ...                       Detroit               Pistons
# 154            ...                       Detroit               Pistons
# 161            ...                       Atlanta                 Hawks
# 176            ...                       Detroit               Pistons
# 190            ...                       Detroit               Pistons
# 206            ...                       Detroit               Pistons
# 240            ...                       Detroit               Pistons
# 248            ...                       Atlanta                 Hawks
# 260            ...                       Atlanta                 Hawks
# 261            ...                       Detroit               Pistons
# 265            ...                       Detroit               Pistons
# 268            ...                       Detroit               Pistons
# 279            ...                       Atlanta                 Hawks
# 282            ...                       Atlanta                 Hawks
# 284            ...                       Atlanta                 Hawks
# ..             ...                           ...                   ...
# 47             ...                    Washington               Wizards
# 65             ...                    Washington               Wizards
# 66             ...                       Orlando                 Magic
# 67             ...                    Washington               Wizards
# 72             ...                       Orlando                 Magic
# 78             ...                       Orlando                 Magic
# 81             ...                       Orlando                 Magic
# 82             ...                    Washington               Wizards
# 105            ...                       Orlando                 Magic
# 120            ...                    Washington               Wizards
# 128            ...                       Orlando                 Magic
# 148            ...                       Orlando                 Magic
# 155            ...                       Orlando                 Magic
# 169            ...                    Washington               Wizards
# 171            ...                    Washington               Wizards
# 172            ...                       Orlando                 Magic
# 190            ...                    Washington               Wizards
# 202            ...                       Orlando                 Magic
# 203            ...                    Washington               Wizards
# 205            ...                    Washington               Wizards
# 267            ...                    Washington               Wizards
# 310            ...                       Orlando                 Magic
# 321            ...                    Washington               Wizards
# 322            ...                       Orlando                 Magic
# 336            ...                       Orlando                 Magic
# 371            ...                       Orlando                 Magic
# 380            ...                    Washington               Wizards
# 451            ...                       Orlando                 Magic
# 458            ...                       Orlando                 Magic
# 463            ...                       Orlando                 Magic
#
#      PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE PLAYER3_ID  PLAYER3_NAME  \
# 5                          DET            0          0           NaN
# 6                          ATL            0          0           NaN
# 7                          DET            0          0           NaN
# 12                         ATL            0          0           NaN
# 28                         DET            0          0           NaN
# 40                         DET            0          0           NaN
# 46                         DET            0          0           NaN
# 49                         DET            0          0           NaN
# 67                         DET            0          0           NaN
# 70                         ATL            0          0           NaN
# 75                         DET            0          0           NaN
# 92                         ATL            0          0           NaN
# 97                         ATL            0          0           NaN
# 119                        ATL            0          0           NaN
# 121                        DET            0          0           NaN
# 134                        DET            0          0           NaN
# 154                        DET            0          0           NaN
# 161                        ATL            0          0           NaN
# 176                        DET            0          0           NaN
# 190                        DET            0          0           NaN
# 206                        DET            0          0           NaN
# 240                        DET            0          0           NaN
# 248                        ATL            0          0           NaN
# 260                        ATL            0          0           NaN
# 261                        DET            0          0           NaN
# 265                        DET            0          0           NaN
# 268                        DET            0          0           NaN
# 279                        ATL            0          0           NaN
# 282                        ATL            0          0           NaN
# 284                        ATL            0          0           NaN
# ..                         ...          ...        ...           ...
# 47                         WAS            0          0           NaN
# 65                         WAS            0          0           NaN
# 66                         ORL            0          0           NaN
# 67                         WAS            0          0           NaN
# 72                         ORL            0          0           NaN
# 78                         ORL            0          0           NaN
# 81                         ORL            0          0           NaN
# 82                         WAS            0          0           NaN
# 105                        ORL            0          0           NaN
# 120                        WAS            0          0           NaN
# 128                        ORL            0          0           NaN
# 148                        ORL            0          0           NaN
# 155                        ORL            0          0           NaN
# 169                        WAS            0          0           NaN
# 171                        WAS            0          0           NaN
# 172                        ORL            0          0           NaN
# 190                        WAS            0          0           NaN
# 202                        ORL            0          0           NaN
# 203                        WAS            0          0           NaN
# 205                        WAS            0          0           NaN
# 267                        WAS            0          0           NaN
# 310                        ORL            0          0           NaN
# 321                        WAS            0          0           NaN
# 322                        ORL            0          0           NaN
# 336                        ORL            0          0           NaN
# 371                        ORL            0          0           NaN
# 380                        WAS            0          0           NaN
# 451                        ORL            0          0           NaN
# 458                        ORL            0          0           NaN
# 463                        ORL            0          0           NaN
#
#     PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 5               NaN               NaN                   NaN
# 6               NaN               NaN                   NaN
# 7               NaN               NaN                   NaN
# 12              NaN               NaN                   NaN
# 28              NaN               NaN                   NaN
# 40              NaN               NaN                   NaN
# 46              NaN               NaN                   NaN
# 49              NaN               NaN                   NaN
# 67              NaN               NaN                   NaN
# 70              NaN               NaN                   NaN
# 75              NaN               NaN                   NaN
# 92              NaN               NaN                   NaN
# 97              NaN               NaN                   NaN
# 119             NaN               NaN                   NaN
# 121             NaN               NaN                   NaN
# 134             NaN               NaN                   NaN
# 154             NaN               NaN                   NaN
# 161             NaN               NaN                   NaN
# 176             NaN               NaN                   NaN
# 190             NaN               NaN                   NaN
# 206             NaN               NaN                   NaN
# 240             NaN               NaN                   NaN
# 248             NaN               NaN                   NaN
# 260             NaN               NaN                   NaN
# 261             NaN               NaN                   NaN
# 265             NaN               NaN                   NaN
# 268             NaN               NaN                   NaN
# 279             NaN               NaN                   NaN
# 282             NaN               NaN                   NaN
# 284             NaN               NaN                   NaN
# ..              ...               ...                   ...
# 47              NaN               NaN                   NaN
# 65              NaN               NaN                   NaN
# 66              NaN               NaN                   NaN
# 67              NaN               NaN                   NaN
# 72              NaN               NaN                   NaN
# 78              NaN               NaN                   NaN
# 81              NaN               NaN                   NaN
# 82              NaN               NaN                   NaN
# 105             NaN               NaN                   NaN
# 120             NaN               NaN                   NaN
# 128             NaN               NaN                   NaN
# 148             NaN               NaN                   NaN
# 155             NaN               NaN                   NaN
# 169             NaN               NaN                   NaN
# 171             NaN               NaN                   NaN
# 172             NaN               NaN                   NaN
# 190             NaN               NaN                   NaN
# 202             NaN               NaN                   NaN
# 203             NaN               NaN                   NaN
# 205             NaN               NaN                   NaN
# 267             NaN               NaN                   NaN
# 310             NaN               NaN                   NaN
# 321             NaN               NaN                   NaN
# 322             NaN               NaN                   NaN
# 336             NaN               NaN                   NaN
# 371             NaN               NaN                   NaN
# 380             NaN               NaN                   NaN
# 451             NaN               NaN                   NaN
# 458             NaN               NaN                   NaN
# 463             NaN               NaN                   NaN
#
#      PLAYER3_TEAM_ABBREVIATION
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 12                         NaN
# 28                         NaN
# 40                         NaN
# 46                         NaN
# 49                         NaN
# 67                         NaN
# 70                         NaN
# 75                         NaN
# 92                         NaN
# 97                         NaN
# 119                        NaN
# 121                        NaN
# 134                        NaN
# 154                        NaN
# 161                        NaN
# 176                        NaN
# 190                        NaN
# 206                        NaN
# 240                        NaN
# 248                        NaN
# 260                        NaN
# 261                        NaN
# 265                        NaN
# 268                        NaN
# 279                        NaN
# 282                        NaN
# 284                        NaN
# ..                         ...
# 47                         NaN
# 65                         NaN
# 66                         NaN
# 67                         NaN
# 72                         NaN
# 78                         NaN
# 81                         NaN
# 82                         NaN
# 105                        NaN
# 120                        NaN
# 128                        NaN
# 148                        NaN
# 155                        NaN
# 169                        NaN
# 171                        NaN
# 172                        NaN
# 190                        NaN
# 202                        NaN
# 203                        NaN
# 205                        NaN
# 267                        NaN
# 310                        NaN
# 321                        NaN
# 322                        NaN
# 336                        NaN
# 371                        NaN
# 380                        NaN
# 451                        NaN
# 458                        NaN
# 463                        NaN
#
# [171 rows x 33 columns]

# %%
# for each assist event ....
curPath = os.getcwd()
print curPath
SportVU_JSON_Rootpath = "D:\\DataMining-NBA-Repo\\JupyterNotebooks\\SportVU_JSON_Data\\"
#print SportVU_JSON_Rootpath+str(gameid)+".json"
gameid_prev = 0;
for index, ast in AST_df.iterrows():
    gameid = ast["GAME_ID"]    #game id from PBP
    eventNumPBP = ast["EVENTNUM"] #eventNumber for the play
    gametimePBP = ast["PCTIMESTRING"]  #game time for the play
    quarterPBP = int(ast["PERIOD"])
    print("prevGameID:"+str(gameid_prev)+", currentlyAnalyzingGameID:"+str(gameid))
    print("PBPEventNum:"+str(eventNumPBP)+", gametimePBP:"+str(gametimePBP))
    #check if SportVU json data is already opened for this PBP play
    if(gameid_prev != gameid):
        #open raw JSON SportVU data using game id from assist
        with open(SportVU_JSON_Rootpath+"00"+str(gameid)+".json") as data_file:    
            rawSportVUData = json.load(data_file)
            json_normalize(rawSportVUData['events'])
        gameid_prev = gameid
    
    #get the correct eventNum (returned as long) in SportsVU
    eventNumSportsVU = findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, eventNumPBP)
    
    #extract SportsVU movements for that eventNum
    #rawpossessionSportsVU = MomentsfromEventNum(rawSportVUData, int(eventNumSportsVU))
# Out:
# D:\DataMining-NBA-Repo\JupyterNotebooks\pbp-csv
# prevGameID:0, currentlyAnalyzingGameID:21500001
# PBPEventNum:5, gametimePBP:11:21
# Finding correctSportVU eventNum gameid:0021500001
# 681
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:681 SportsVU moment clock:683.22
# extracted event num 5
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:6, gametimePBP:11:00
# Finding correctSportVU eventNum gameid:0021500001
# 660
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:660 SportsVU moment clock:662.29
# extracted event num 6
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:7, gametimePBP:10:44
# Finding correctSportVU eventNum gameid:0021500001
# 644
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:644 SportsVU moment clock:647.34
# extracted event num 7
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:13, gametimePBP:10:01
# Finding correctSportVU eventNum gameid:0021500001
# 601
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:601 SportsVU moment clock:582.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:601 SportsVU moment clock:603.49
# extracted event num 12
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:33, gametimePBP:8:11
# Finding correctSportVU eventNum gameid:0021500001
# 491
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:491 SportsVU moment clock:461.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:491 SportsVU moment clock:461.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:491 SportsVU moment clock:475.78
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:491 SportsVU moment clock:492.79
# extracted event num 30
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:47, gametimePBP:6:48
# Finding correctSportVU eventNum gameid:0021500001
# 408
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:391.64
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:399.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:399.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:399.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:399.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:399.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:408 SportsVU moment clock:409.97
# extracted event num 41
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:55, gametimePBP:6:30
# Finding correctSportVU eventNum gameid:0021500001
# 390
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:358.39
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:358.39
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:358.39
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:365.44
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:390 SportsVU moment clock:391.64
# extracted event num 48
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:58, gametimePBP:5:57
# Finding correctSportVU eventNum gameid:0021500001
# 357
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:315.07
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:315.07
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:337.23
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:357 SportsVU moment clock:358.39
# extracted event num 52
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:77, gametimePBP:4:23
# Finding correctSportVU eventNum gameid:0021500001
# 263
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:203.05
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:215.07
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:223.09
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:233.11
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:233.11
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:255.15
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:255.15
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:263 SportsVU moment clock:263.0
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:81, gametimePBP:4:13
# Finding correctSportVU eventNum gameid:0021500001
# 253
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:197.03
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:197.03
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:202.04
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:203.05
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:215.07
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:223.09
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:233.11
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:233.11
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:253 SportsVU moment clock:255.15
# extracted event num 72
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:86, gametimePBP:3:33
# Finding correctSportVU eventNum gameid:0021500001
# 213
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:167.98
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:197.03
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:197.03
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:202.04
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:203.05
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:213 SportsVU moment clock:215.07
# extracted event num 76
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:105, gametimePBP:1:47
# Finding correctSportVU eventNum gameid:0021500001
# 107
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:2.4
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:2.4
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:32.63
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:32.63
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:44.62
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:69.6
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:81.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:107 SportsVU moment clock:108.97
# extracted event num 94
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:110, gametimePBP:0:32
# Finding correctSportVU eventNum gameid:0021500001
# 32
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:32 SportsVU moment clock:697.99
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:32 SportsVU moment clock:720.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:32 SportsVU moment clock:720.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:32 SportsVU moment clock:720.0
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:2.4
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:2.4
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:2.4
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:13.53
# PBP quareter: str(quarterPBP) quartersportVU :1
# PBP gameclock:32 SportsVU moment clock:32.63
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:132, gametimePBP:10:31
# Finding correctSportVU eventNum gameid:0021500001
# 631
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:573.62
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:573.62
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:582.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:596.87
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:601.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:601.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:608.75
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:621.96
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:621.96
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:623.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:631 SportsVU moment clock:632.24
# extracted event num 119
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:137, gametimePBP:10:20
# Finding correctSportVU eventNum gameid:0021500001
# 620
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:509.97
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:509.97
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:529.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:529.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:541.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:562.83
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:573.62
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:573.62
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:582.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:596.87
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:601.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:601.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:608.75
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:620 SportsVU moment clock:621.96
# extracted event num 122
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:150, gametimePBP:8:48
# Finding correctSportVU eventNum gameid:0021500001
# 528
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:469.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:469.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:469.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:489.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:503.02
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:509.97
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:509.97
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:528 SportsVU moment clock:529.83
# extracted event num 135
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:172, gametimePBP:7:06
# Finding correctSportVU eventNum gameid:0021500001
# 426
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:330.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:330.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:347.0
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:366.56
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:366.56
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:366.56
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:366.56
# PBP quareter: str(quarterPBP) quartersportVU :2
# PBP gameclock:426 SportsVU moment clock:366.56
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-ec698d749bec> in <module>()
#      21
#      22     #get the correct eventNum (returned as long) in SportsVU
# ---> 23     eventNumSportsVU = findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, eventNumPBP)
#      24
#      25     #extract SportsVU movements for that eventNum
#
# <ipython-input-14-f4b4ce679e87> in findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, approxEventNumPBP)
#       8     while (found == False):
#       9         moments = MomentsfromEventNum(rawSportVUData, approxEventNumPBP)
# ---> 10         quarterSportVU = int(moments[0][0])
#      11         print("PBP quareter: str(quarterPBP) "+"quartersportVU :"+str(quarterSportVU))
#      12         print("PBP gameclock:"+str(gameInSeconds)+" SportsVU moment clock:"+str(moments[0][2]))
#
# IndexError: list index out of range

# %% [markdown]
# ## Loop through queried events
# ## Extract EventNum from Movement dataset
# ## Save to new dataframe
# ## Append event's specific column to this dataframe row

# %%
#for i, row in events_queried.iterrows():
for i in range(events_queried.shape[0]):
    #extract the row from events dataframe
    extractedRow = events_queried.iloc[i]
    print extractedRow
    #movement_events_df.append(extractedRow,ignore_index=True)
    movement_events_df = movement_events_df.append(pd.DataFrame(extractedRow), ignore_index=True)
    #movement_events_df = pd.concat([movement_events_df, row], axis=1)
