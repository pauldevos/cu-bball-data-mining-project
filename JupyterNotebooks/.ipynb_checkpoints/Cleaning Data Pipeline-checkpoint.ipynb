# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import numpy as np 
#for importing files
import glob, os
import matplotlib.pyplot as plt
# %matplotlib inline


#Library for hull calculation
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
from matplotlib.path import Path
from scipy.spatial import distance

# %% [markdown]
# ## Helper Methods

# %%
def SecsToGameTime(time):
    mins=(int(time)/60)
    secs=int(time)%60
    print (str(mins)+":"+str(secs))

# %%
def GameTimetoSeconds(time):
    mins, secs = time.split(":")
    timeSecs = int(mins)*60+int(secs)
    print(timeSecs)
    return timeSecs

# %% [markdown]
# #### Hull Calculation Helper Method

# %%
def getHull(moments, teamID):
    points = []
    
    if(int(moments[5][1][0]) == teamID):
        for positions in moments[5][1:6]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    else:
        for positions in moments[5][6:11]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    
    np_points = np.asarray(points)
    np_points
    hull = ConvexHull(np_points)
    
    return hull,np_points

# %%
def distFromCentroid(hull, x,y):
        cx = np.mean(hull.points[hull.vertices,0])
        cy = np.mean(hull.points[hull.vertices,1])
        return ((x-cx)^2+(y-cy)^2)^.5

# %%
def isInHull(hull,np_points,x,y):
    #point in hull?
    hull_path = Path( np_points[hull.vertices] )
    isInPath = hull_path.contains_point((x,y))
    return (isInPath == True)

# %% [markdown]
# ### Helper method for returning PBP descriptions given game and eventNum

# %%
def getPBPInfo(gameID,PBPEventNum):
    curPath = os.getcwd()
    if(not curPath.endswith('\pbp-csv')):
        curPath = os.getcwd()
        print curPath
        strIndex=curPath.index('\\JupyterNotebooks')
        curPath = curPath[:(strIndex+18)]+'\pbp-csv'
        os.chdir(curPath)
        print curPath
    
    events_df = pd.read_csv("00"+str(gameID)+".csv")
    eventRow = events_df[events_df['EVENTNUM'].isin([int(PBPEventNum)])]
     
    print eventRow['PCTIMESTRING']
    print eventRow['HOMEDESCRIPTION']
    print eventRow['VISITORDESCRIPTION']
    return eventRow['PCTIMESTRING'] , eventRow['HOMEDESCRIPTION'] , eventRow['VISITORDESCRIPTION]

# %% [markdown]
# ### Given the game time (12:00) and eventNumber from the Play-by-play data for a recorded event, this method returns the correct eventNumber from the SportsVU data since they actually dont matchup.  This method converts the gametime into seconds (720s = 12:00) which is formatted in SportsVU.  It traverses up and down events until the gametime is within a selected eventNumber.

# %%
def findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, approxEventNumPBP):
    print("Finding correct SportVU eventNum for gameid:"+rawSportVUData['gameid'])

    found = False;
    moments = None
    #convert gametimePBP (12:00) to seconds (720)
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    while (found == False):
        print("Currently checking eventNumPBP: "+str(approxEventNumPBP))
        moments, SportVUEventIndex = MomentsfromEventNum(rawSportVUData, approxEventNumPBP)
        if (moments is None or len(moments) == 0 or SportVUEventIndex  is None):
            return None
        
        quarterSportVU = int(moments[0][0])
        #print("PBP quareter:"+str(quarterPBP)+"quartersportVU :"+str(quarterSportVU))
        #print("PBP gameclock:"+str(gameInSeconds)+" SportsVU moment clock:"+str(moments[0][2]))
        
        #check whether this EventNum moment is the correct time frame of the play from Play-by-play
        if(quarterPBP < quarterSportVU):
            approxEventNumPBP -= 1
        elif(quarterPBP > quarterSportVU):    
            approxEventNumPBP  += 1
        elif(int(moments[0][2]) > gameInSeconds and int(moments[len(moments)-1][2]) < gameInSeconds):
            found=True
        elif(moments[0][2] < gameInSeconds):
            approxEventNumPBP -= 1
        elif(moments[len(moments)-1][2] > gameInSeconds):
        # look ahead 1 event 
            approxEventNumPBP += 1
        else:
            return None
    #print("extracted event num "+ str(approxEventNumPBP))
    return approxEventNumPBP

# %%
def MomentsfromEventNum(eventsData, eventNumPBP):
    found = False
    searchDirection = None
    sportVUIndex = eventNumPBP
    eventsLen = len(eventsData['events'])-1
    if(eventsLen < sportVUIndex):
        sportVUIndex = eventsLen
    
    while(not found):        
        if( int(eventsData['events'][sportVUIndex]['eventId']) == eventNumPBP):
            found = True
        elif ( int(eventsData['events'][sportVUIndex]['eventId']) > eventNumPBP ):
            if(searchDirection is None and sportVUIndex > 0):
                searchDirection = "decrementIndex"
                sportVUIndex -= 1  
            elif(searchDirection is "decrementIndex" and sportVUIndex > 0):
                sportVUIndex -= 1  
            elif(searchDirection is "incrementIndex"):
                return None
            else: #we have reached 0th index and cant traverse up the list anymore
                return None
        elif ( int(eventsData['events'][sportVUIndex]['eventId']) < eventNumPBP ):
            if(searchDirection is None and sportVUIndex < eventsLen):
                searchDirection = "incrementIndex"
                sportVUIndex += 1  
            elif(searchDirection is "incrementIndex" and sportVUIndex < eventsLen):
                sportVUIndex += 1  
            elif(searchDirection is "decrementIndex"):
                return None
            else: #we have reached 0th index and cant traverse up the list anymore
                return None
    print("sportVU Index for the eventNumPBP: "+str(sportVUIndex))
    
    return eventsData['events'][sportVUIndex]["moments"], sportVUIndex

# %% [markdown]
# ## Identify Moment of CATCH
#
# 1.  //sort events moment data from end time to beginning (reverse order)
# timeballReceived, locationballReceived = getReceive (recieverID, List[Moments])
#
# Each moment is taken every .25s, so the FIRST 8 moments (8 *.25 = 2 seconds) when the receiverID and ball are within (dist <= 1 ft), is when the ball was the moment before the ball was released.
#
# reset numCount = 0;
#
# Starting from this time, continue iterating through moments. If dist from receiver and ball >=1 ft, then this is time the ball was caught.
#
# ***separate calculation to check when the ball dist less than 1 ft for another teammate to determine if it was a pass in a certain amount of time (counted numCount)****
#
# 2.  Find "latest" instance when   distFrom ( Moment.Positions[0].x,Moment.Position[0].y , Moment.Position[ ??=playerID ].x , Moment.Position[ ??=playerID].y) <= 1ft )
#
#    return the timemilis ,  position[0].x , position[0].y

# %%
 def getCatchEventDetails(receiverID, passerID, gametimePBP, moments):
    momentsReversed = moments[::-1]
    processComplete = False;
    indexBallCaught = None
    indexBallReleased = None
    finalIndex=0
    index=0
    found = False
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    print("num of moments: "+str(len(momentsReversed)))
    while (found == False):
        if(int(momentsReversed[index][2]) >=  gameInSeconds):
            found=True
        elif(int(momentsReversed[index][2]< gameInSeconds)):
            index += 1
        else:
            return "ERROR"
    
    print("starting at time: "+ str(momentsReversed[index][2]))
    
    #Found the index of the approx start of the event
    numCounts=0
    for i in range(index,len(momentsReversed)):
        if numCounts >= 3:
            timeBallReleased = momentsReversed[i][2]
            SecsToGameTime(timeBallReleased)  
            indexBallReleased = i
            break
        else:
            ball = momentsReversed[i][5][0]
            for positions in momentsReversed[i][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("receiver holding ball: " + str( momentsReversed[i][3]))
                numCounts += 1
    
    #check if ball caught event in moments list
    if(indexBallReleased is None):            
        return None, None, None, None, None, None, None, None, None, None
    
    #count when ball is caught
    numCounts=0
    for j in range(indexBallReleased, len(momentsReversed)):
        if numCounts >= 3:
            timeBallCaught = momentsReversed[j][2]
            SecsToGameTime(timeBallCaught)
            indexBallCaught = j
            
            #record position of receiver
            receiverMoment = momentsReversed[j][5]
            receiverPos = [k for k in receiverMoment if receiverID in k]
            
            reciever_pos_x = receiverPos[0][2]
            receiver_pos_y = receiverPos[0][3]
            receiverPosAtCaught = [reciever_pos_x, receiver_pos_y]
            
            break
        else:
            ball = momentsReversed[j][5][0]
            for positions in momentsReversed[j][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist >= 2:
                print("receiver just caught ball: " + str(momentsReversed[j][3])+" received reversed index"+str(j))
                SecsToGameTime(momentsReversed[j][3])
                numCounts += 1
            if(momentsReversed[j][3] is None):            
                return None, None, None, None, None, None, None, None, None, None   
            
    
    
    #check if ball caught event in moments list
    if(indexBallCaught is None):            
        return None, None, None, None, None, None, None, None, None, None   
                
                
    #count when ball is passed
    numCounts=0
    for k in range(indexBallCaught, len(momentsReversed)):
        if numCounts >= 2:
            print("player PASSED ball at "+str(momentsReversed[k][3]))
            timeBallPassed = momentsReversed[k][2]
            SecsToGameTime(timeBallPassed)
            indexBallPassed = k
            processComplete = True
               
            #record position of receiver
            receiverMoment = momentsReversed[k][5]
            receiverPos = [k for k in receiverMoment if receiverID in k]
            
            reciever_pos_x = receiverPos[0][2]
            receiver_pos_y = receiverPos[0][3]
            receiverPosAtPass = [reciever_pos_x ,receiver_pos_y]
        
            #record position of passer
            passerPos = [k for k in receiverMoment if passerID in k]
            
            passer_pos_x = passerPos[0][2]
            passer_pos_y = passerPos[0][3]
            passerPosAtPass = [passer_pos_x ,passer_pos_y]
            
            SportsVUReversedIndex = len(momentsReversed) - indexBallPassed
            
            break
        else:
            ball = momentsReversed[k][5][0]
            for positions in momentsReversed[k][5]:
                if positions[1] == passerID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("passer just passed ball: " +str(momentsReversed[k][3]) + " passed reversed index"+str(k))
                numCounts += 1
            
            
                
    
    if(not processComplete):            
        return None, None, None, None, None, None, None, None, None , None
    
        
    return timeBallReleased, indexBallReleased, timeBallCaught, indexBallCaught, timeBallPassed, indexBallPassed, receiverPosAtPass, receiverPosAtCaught, passerPosAtPass, SportsVUReversedIndex

# %% [markdown]
# ### Extracts Assists, Bad Passes, Alley Oops from csvs in current directory and saves them into separate csv files

# %%
AST_df = pd.DataFrame()
BadPass_df = pd.DataFrame()
AlleyOop_df = pd.DataFrame()
curPath = os.getcwd()
print curPath
if(not curPath.endswith('\pbp-csv')):
    curPath = os.getcwd()
    print curPath
    strIndex=curPath.index('\\JupyterNotebooks')
    curPath = curPath[:(strIndex+18)]+'\pbp-csv'
    os.chdir(curPath)
    print curPath
for pbpFile in glob.glob("*.csv"):
    print(pbpFile)
    #read file as df
    events_df = pd.read_csv(pbpFile)
    ASTList = events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("AST", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("AST", na = False )  ) ]
    BadPassList= events_df[( events_df['VISITORDESCRIPTION'].str.contains("Bad", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Bad", na = False )  ) ]
    AlleyOopList= events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("Alley", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Alley", na = False )  ) ]
    AST_df = AST_df.append(ASTList)
    BadPass_df = BadPass_df.append(BadPassList)
    AlleyOop_df = AlleyOop_df.append(AlleyOopList)
    
AST_df.to_csv("AST_Parsed.csv", sep='\t')
BadPass_df.to_csv("BadPass_Parsed.csv", sep='\t')
AlleyOop_df.to_csv("AlleyOop_Parsed.csv", sep='\t')
# Out:
# D:\DataMining-NBA-Repo\JupyterNotebooks\pbp-csv
# 0021500001.csv
# 0021500002.csv

# %% [markdown]
# ## AST_df  assists data frame has time and event num of all assists....

# %%
AST_df
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 5    21500001         5             1                  80       1
# 6    21500001         6             1                  80       1
# 7    21500001         7             1                 101       1
# 12   21500001        13             1                 105       1
# 28   21500001        33             1                   7       1
# 40   21500001        47             1                   1       1
# 46   21500001        55             1                  63       1
# 49   21500001        58             1                   1       1
# 67   21500001        77             1                 101       1
# 70   21500001        81             1                  98       1
# 75   21500001        86             1                  43       1
# 92   21500001       105             1                  42       1
# 97   21500001       110             1                   1       1
# 119  21500001       132             1                   1       2
# 121  21500001       137             1                   1       2
# 134  21500001       150             1                   1       2
# 154  21500001       172             1                   1       2
# 161  21500001       180             1                  41       2
# 176  21500001       197             1                   1       2
# 190  21500001       214             1                   1       2
# 206  21500001       232             1                  50       2
# 240  21500001       269             1                  79       3
# 248  21500001       282             1                  79       3
# 260  21500001       294             1                   1       3
# 261  21500001       295             1                  42       3
# 265  21500001       301             1                   1       3
# 268  21500001       304             1                  63       3
# 279  21500001       317             1                   7       3
# 282  21500001       321             1                   1       3
# 284  21500001       324             1                  44       3
# ..        ...       ...           ...                 ...     ...
# 134  21500002       154             1                   1       2
# 136  21500002       156             1                  99       2
# 179  21500002       205             1                  76       2
# 200  21500002       232             1                   1       2
# 217  21500002       251             1                  41       2
# 221  21500002       255             1                   1       2
# 228  21500002       263             1                   1       2
# 241  21500002       278             1                   1       2
# 242  21500002       279             1                   1       2
# 249  21500002       286             1                 101       2
# 260  21500002       299             1                  74       3
# 261  21500002       300             1                   1       3
# 262  21500002       301             1                   1       3
# 267  21500002       307             1                 108       3
# 268  21500002       308             1                   1       3
# 279  21500002       320             1                   1       3
# 302  21500002       346             1                  99       3
# 321  21500002       366             1                  82       3
# 336  21500002       382             1                   1       3
# 338  21500002       385             1                  75       3
# 343  21500002       391             1                  98       3
# 364  21500002       418             1                   1       4
# 373  21500002       427             1                   1       4
# 387  21500002       443             1                   1       4
# 413  21500002       473             1                  79       4
# 416  21500002       479             1                   7       4
# 454  21500002       526             1                  99       4
# 471  21500002       548             1                   1       4
# 472  21500002       549             1                   1       4
# 475  21500002       552             1                   1       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 5        8:13 PM        11:21
# 6        8:13 PM        11:00
# 7        8:14 PM        10:44
# 12       8:14 PM        10:01
# 28       8:17 PM         8:11
# 40       8:22 PM         6:48
# 46       8:23 PM         6:30
# 49       8:24 PM         5:57
# 67       8:26 PM         4:23
# 70       8:27 PM         4:13
# 75       8:27 PM         3:33
# 92       8:32 PM         1:47
# 97       8:33 PM         0:32
# 119      8:40 PM        10:31
# 121      8:43 PM        10:20
# 134      8:45 PM         8:48
# 154      8:48 PM         7:06
# 161      8:49 PM         6:05
# 176      8:54 PM         4:35
# 190      8:57 PM         2:50
# 206      9:02 PM         0:55
# 240      9:24 PM         8:37
# 248      9:28 PM         7:42
# 260      9:31 PM         5:55
# 261      9:31 PM         5:39
# 265      9:33 PM         5:13
# 268      9:34 PM         4:50
# 279      9:35 PM         4:10
# 282      9:36 PM         3:32
# 284      9:37 PM         2:52
# ..           ...          ...
# 134      8:34 PM        11:02
# 136      8:35 PM        10:21
# 179      8:44 PM         7:08
# 200      8:50 PM         5:17
# 217      8:53 PM         3:40
# 221      8:53 PM         3:20
# 228      8:57 PM         2:35
# 241      8:59 PM         1:31
# 242      9:00 PM         1:16
# 249      9:01 PM         0:23
# 260      9:20 PM        10:57
# 261      9:20 PM        10:47
# 262      9:21 PM        10:29
# 267      9:22 PM         9:52
# 268      9:22 PM         9:37
# 279      9:24 PM         8:27
# 302      9:32 PM         5:38
# 321      9:35 PM         4:21
# 336      9:36 PM         2:48
# 338      9:37 PM         2:14
# 343      9:41 PM         1:37
# 364      9:48 PM        11:30
# 373      9:49 PM        10:23
# 387      9:51 PM         9:18
# 413     10:02 PM         6:42
# 416     10:04 PM         6:01
# 454     10:15 PM         2:21
# 471     10:20 PM         1:15
# 472     10:21 PM         1:02
# 475     10:21 PM         0:32
#
#                                        HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 5                                                  NaN                 NaN
# 6    Millsap 12' Step Back Jump Shot (2 PTS) (Korve...                 NaN
# 7                                                  NaN                 NaN
# 12   Millsap 12' Turnaround Fadeaway Bank Jump Shot...                 NaN
# 28                                                 NaN                 NaN
# 40                                                 NaN                 NaN
# 46                                                 NaN                 NaN
# 49                                                 NaN                 NaN
# 67                                                 NaN                 NaN
# 70   Schroder 1' Cutting Layup Shot (2 PTS) (Millsa...                 NaN
# 75                                                 NaN                 NaN
# 92   Schroder 2' Driving Layup (4 PTS) (Patterson 1...                 NaN
# 97   Patterson  3PT Jump Shot (3 PTS) (Schroder 1 AST)                 NaN
# 119  Horford 24' 3PT Jump Shot (3 PTS) (Schroder 2 ...                 NaN
# 121                                                NaN                 NaN
# 134                                                NaN                 NaN
# 154                                                NaN                 NaN
# 161  Teague 2' Running Layup (8 PTS) (Sefolosha 1 AST)                 NaN
# 176                                                NaN                 NaN
# 190                                                NaN                 NaN
# 206                                                NaN                 NaN
# 240                                                NaN                 NaN
# 248  Korver 20' Pullup Jump Shot (2 PTS) (Horford 2...                 NaN
# 260  Millsap 25' 3PT Jump Shot (13 PTS) (Teague 1 AST)                 NaN
# 261                                                NaN                 NaN
# 265                                                NaN                 NaN
# 268                                                NaN                 NaN
# 279           Splitter  Dunk (4 PTS) (Sefolosha 2 AST)                 NaN
# 282  Schroder 25' 3PT Jump Shot (11 PTS) (Millsap 2...                 NaN
# 284  Millsap 2' Reverse Layup (15 PTS) (Sefolosha 3...                 NaN
# ..                                                 ...                 ...
# 134                                                NaN                 NaN
# 136                                                NaN                 NaN
# 179                                                NaN                 NaN
# 200                                                NaN                 NaN
# 217                                                NaN                 NaN
# 221       Snell 25' 3PT Jump Shot (5 PTS) (Noah 1 AST)                 NaN
# 228                                                NaN                 NaN
# 241                                                NaN                 NaN
# 242  McDermott 25' 3PT Jump Shot (5 PTS) (Butler 2 ...                 NaN
# 249  McDermott 17' Driving Floating Jump Shot (7 PT...                 NaN
# 260                                                NaN                 NaN
# 261    Mirotic 26' 3PT Jump Shot (14 PTS) (Rose 2 AST)                 NaN
# 262                                                NaN                 NaN
# 267                                                NaN                 NaN
# 268           Gasol 17' Jump Shot (2 PTS) (Rose 3 AST)                 NaN
# 279      Snell 25' 3PT Jump Shot (10 PTS) (Rose 4 AST)                 NaN
# 302                                                NaN                 NaN
# 321                                                NaN                 NaN
# 336                                                NaN                 NaN
# 338                                                NaN                 NaN
# 343                                                NaN                 NaN
# 364                                                NaN                 NaN
# 373      Moore 24' 3PT Jump Shot (11 PTS) (Noah 3 AST)                 NaN
# 387          Gibson 14' Jump Shot (5 PTS) (Noah 4 AST)                 NaN
# 413                                                NaN                 NaN
# 416                                                NaN                 NaN
# 454                                                NaN                 NaN
# 471         Butler 19' Jump Shot (17 PTS) (Rose 5 AST)                 NaN
# 472                                                NaN                 NaN
# 475                                                NaN                 NaN
#
#                                     VISITORDESCRIPTION  \
# 5    Marc Morris 13' Step Back Jump Shot (2 PTS) (D...
# 6                                                  NaN
# 7    Caldwell-Pope 9' Driving Floating Jump Shot (2...
# 12                                                 NaN
# 28             Drummond  Dunk (2 PTS) (Ilyasova 2 AST)
# 40   Ilyasova 24' 3PT Jump Shot (3 PTS) (Marc Morri...
# 46   Marc Morris 20' Fadeaway Jumper (7 PTS) (Jacks...
# 49   Caldwell-Pope 24' 3PT Jump Shot (5 PTS) (Jacks...
# 67   Jackson 9' Driving Floating Jump Shot (5 PTS) ...
# 70                                                 NaN
# 75   Drummond  Alley Oop Layup (4 PTS) (Jackson 3 AST)
# 92                                                 NaN
# 97                                                 NaN
# 119                                                NaN
# 121    Blake 24' 3PT Jump Shot (3 PTS) (Johnson 1 AST)
# 134    Johnson 24' 3PT Jump Shot (3 PTS) (Blake 1 AST)
# 154  Ilyasova 26' 3PT Jump Shot (6 PTS) (Johnson 2 ...
# 161                                                NaN
# 176  Marc Morris 25' 3PT Jump Shot (10 PTS) (Caldwe...
# 190  Caldwell-Pope 25' 3PT Jump Shot (8 PTS) (Jacks...
# 206  Caldwell-Pope  Running Dunk (10 PTS) (Drummond...
# 240  Caldwell-Pope 19' Pullup Jump Shot (12 PTS) (D...
# 248                                                NaN
# 260                                                NaN
# 261  Ilyasova 1' Driving Layup (11 PTS) (Jackson 5 ...
# 265  Caldwell-Pope 24' 3PT Jump Shot (19 PTS) (Marc...
# 268  Ilyasova 16' Fadeaway Jumper (13 PTS) (Marc Mo...
# 279                                                NaN
# 282                                                NaN
# 284                                                NaN
# ..                                                 ...
# 134   Williams 26' 3PT Jump Shot (5 PTS) (Smith 1 AST)
# 136  Williams 3' Cutting Finger Roll Layup Shot (7 ...
# 179  James 1' Running Finger Roll Layup (10 PTS) (W...
# 200     Williams  3PT Jump Shot (10 PTS) (Smith 2 AST)
# 217    Jefferson 2' Running Layup (5 PTS) (Love 2 AST)
# 221                                                NaN
# 228  Love 24' 3PT Jump Shot (5 PTS) (Dellavedova 2 ...
# 241  Dellavedova 21' Jump Shot (2 PTS) (Jefferson 1...
# 242                                                NaN
# 249                                                NaN
# 260  James 2' Running Reverse Layup (17 PTS) (Willi...
# 261                                                NaN
# 262        Love 21' Jump Shot (7 PTS) (Williams 5 AST)
# 267     Mozgov  Cutting Dunk Shot (5 PTS) (Love 3 AST)
# 268                                                NaN
# 279                                                NaN
# 302  Love 3' Cutting Finger Roll Layup Shot (9 PTS)...
# 321  Dellavedova 11' Driving Bank Shot (4 PTS) (Moz...
# 336  Jefferson 25' 3PT Jump Shot (8 PTS) (Smith 3 AST)
# 338  Smith 3' Driving Finger Roll Layup (6 PTS) (De...
# 343  Jefferson 2' Cutting Layup Shot (10 PTS) (Will...
# 364  Williams 26' 3PT Jump Shot (17 PTS) (Dellavedo...
# 373                                                NaN
# 387                                                NaN
# 413  Williams 17' Pullup Jump Shot (19 PTS) (Love 4...
# 416            Thompson  Dunk (2 PTS) (Williams 7 AST)
# 454  Dellavedova 1' Cutting Finger Roll Layup Shot ...
# 471                                                NaN
# 472         Love  3PT Jump Shot (15 PTS) (James 4 AST)
# 475      Love 25' 3PT Jump Shot (18 PTS) (James 5 AST)
#
#                ...             PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  \
# 5              ...                       Detroit               Pistons
# 6              ...                       Atlanta                 Hawks
# 7              ...                       Detroit               Pistons
# 12             ...                       Atlanta                 Hawks
# 28             ...                       Detroit               Pistons
# 40             ...                       Detroit               Pistons
# 46             ...                       Detroit               Pistons
# 49             ...                       Detroit               Pistons
# 67             ...                       Detroit               Pistons
# 70             ...                       Atlanta                 Hawks
# 75             ...                       Detroit               Pistons
# 92             ...                       Atlanta                 Hawks
# 97             ...                       Atlanta                 Hawks
# 119            ...                       Atlanta                 Hawks
# 121            ...                       Detroit               Pistons
# 134            ...                       Detroit               Pistons
# 154            ...                       Detroit               Pistons
# 161            ...                       Atlanta                 Hawks
# 176            ...                       Detroit               Pistons
# 190            ...                       Detroit               Pistons
# 206            ...                       Detroit               Pistons
# 240            ...                       Detroit               Pistons
# 248            ...                       Atlanta                 Hawks
# 260            ...                       Atlanta                 Hawks
# 261            ...                       Detroit               Pistons
# 265            ...                       Detroit               Pistons
# 268            ...                       Detroit               Pistons
# 279            ...                       Atlanta                 Hawks
# 282            ...                       Atlanta                 Hawks
# 284            ...                       Atlanta                 Hawks
# ..             ...                           ...                   ...
# 134            ...                     Cleveland             Cavaliers
# 136            ...                     Cleveland             Cavaliers
# 179            ...                     Cleveland             Cavaliers
# 200            ...                     Cleveland             Cavaliers
# 217            ...                     Cleveland             Cavaliers
# 221            ...                       Chicago                 Bulls
# 228            ...                     Cleveland             Cavaliers
# 241            ...                     Cleveland             Cavaliers
# 242            ...                       Chicago                 Bulls
# 249            ...                       Chicago                 Bulls
# 260            ...                     Cleveland             Cavaliers
# 261            ...                       Chicago                 Bulls
# 262            ...                     Cleveland             Cavaliers
# 267            ...                     Cleveland             Cavaliers
# 268            ...                       Chicago                 Bulls
# 279            ...                       Chicago                 Bulls
# 302            ...                     Cleveland             Cavaliers
# 321            ...                     Cleveland             Cavaliers
# 336            ...                     Cleveland             Cavaliers
# 338            ...                     Cleveland             Cavaliers
# 343            ...                     Cleveland             Cavaliers
# 364            ...                     Cleveland             Cavaliers
# 373            ...                       Chicago                 Bulls
# 387            ...                       Chicago                 Bulls
# 413            ...                     Cleveland             Cavaliers
# 416            ...                     Cleveland             Cavaliers
# 454            ...                     Cleveland             Cavaliers
# 471            ...                       Chicago                 Bulls
# 472            ...                     Cleveland             Cavaliers
# 475            ...                     Cleveland             Cavaliers
#
#      PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE PLAYER3_ID  PLAYER3_NAME  \
# 5                          DET            0          0           NaN
# 6                          ATL            0          0           NaN
# 7                          DET            0          0           NaN
# 12                         ATL            0          0           NaN
# 28                         DET            0          0           NaN
# 40                         DET            0          0           NaN
# 46                         DET            0          0           NaN
# 49                         DET            0          0           NaN
# 67                         DET            0          0           NaN
# 70                         ATL            0          0           NaN
# 75                         DET            0          0           NaN
# 92                         ATL            0          0           NaN
# 97                         ATL            0          0           NaN
# 119                        ATL            0          0           NaN
# 121                        DET            0          0           NaN
# 134                        DET            0          0           NaN
# 154                        DET            0          0           NaN
# 161                        ATL            0          0           NaN
# 176                        DET            0          0           NaN
# 190                        DET            0          0           NaN
# 206                        DET            0          0           NaN
# 240                        DET            0          0           NaN
# 248                        ATL            0          0           NaN
# 260                        ATL            0          0           NaN
# 261                        DET            0          0           NaN
# 265                        DET            0          0           NaN
# 268                        DET            0          0           NaN
# 279                        ATL            0          0           NaN
# 282                        ATL            0          0           NaN
# 284                        ATL            0          0           NaN
# ..                         ...          ...        ...           ...
# 134                        CLE            0          0           NaN
# 136                        CLE            0          0           NaN
# 179                        CLE            0          0           NaN
# 200                        CLE            0          0           NaN
# 217                        CLE            0          0           NaN
# 221                        CHI            0          0           NaN
# 228                        CLE            0          0           NaN
# 241                        CLE            0          0           NaN
# 242                        CHI            0          0           NaN
# 249                        CHI            0          0           NaN
# 260                        CLE            0          0           NaN
# 261                        CHI            0          0           NaN
# 262                        CLE            0          0           NaN
# 267                        CLE            0          0           NaN
# 268                        CHI            0          0           NaN
# 279                        CHI            0          0           NaN
# 302                        CLE            0          0           NaN
# 321                        CLE            0          0           NaN
# 336                        CLE            0          0           NaN
# 338                        CLE            0          0           NaN
# 343                        CLE            0          0           NaN
# 364                        CLE            0          0           NaN
# 373                        CHI            0          0           NaN
# 387                        CHI            0          0           NaN
# 413                        CLE            0          0           NaN
# 416                        CLE            0          0           NaN
# 454                        CLE            0          0           NaN
# 471                        CHI            0          0           NaN
# 472                        CLE            0          0           NaN
# 475                        CLE            0          0           NaN
#
#     PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 5               NaN               NaN                   NaN
# 6               NaN               NaN                   NaN
# 7               NaN               NaN                   NaN
# 12              NaN               NaN                   NaN
# 28              NaN               NaN                   NaN
# 40              NaN               NaN                   NaN
# 46              NaN               NaN                   NaN
# 49              NaN               NaN                   NaN
# 67              NaN               NaN                   NaN
# 70              NaN               NaN                   NaN
# 75              NaN               NaN                   NaN
# 92              NaN               NaN                   NaN
# 97              NaN               NaN                   NaN
# 119             NaN               NaN                   NaN
# 121             NaN               NaN                   NaN
# 134             NaN               NaN                   NaN
# 154             NaN               NaN                   NaN
# 161             NaN               NaN                   NaN
# 176             NaN               NaN                   NaN
# 190             NaN               NaN                   NaN
# 206             NaN               NaN                   NaN
# 240             NaN               NaN                   NaN
# 248             NaN               NaN                   NaN
# 260             NaN               NaN                   NaN
# 261             NaN               NaN                   NaN
# 265             NaN               NaN                   NaN
# 268             NaN               NaN                   NaN
# 279             NaN               NaN                   NaN
# 282             NaN               NaN                   NaN
# 284             NaN               NaN                   NaN
# ..              ...               ...                   ...
# 134             NaN               NaN                   NaN
# 136             NaN               NaN                   NaN
# 179             NaN               NaN                   NaN
# 200             NaN               NaN                   NaN
# 217             NaN               NaN                   NaN
# 221             NaN               NaN                   NaN
# 228             NaN               NaN                   NaN
# 241             NaN               NaN                   NaN
# 242             NaN               NaN                   NaN
# 249             NaN               NaN                   NaN
# 260             NaN               NaN                   NaN
# 261             NaN               NaN                   NaN
# 262             NaN               NaN                   NaN
# 267             NaN               NaN                   NaN
# 268             NaN               NaN                   NaN
# 279             NaN               NaN                   NaN
# 302             NaN               NaN                   NaN
# 321             NaN               NaN                   NaN
# 336             NaN               NaN                   NaN
# 338             NaN               NaN                   NaN
# 343             NaN               NaN                   NaN
# 364             NaN               NaN                   NaN
# 373             NaN               NaN                   NaN
# 387             NaN               NaN                   NaN
# 413             NaN               NaN                   NaN
# 416             NaN               NaN                   NaN
# 454             NaN               NaN                   NaN
# 471             NaN               NaN                   NaN
# 472             NaN               NaN                   NaN
# 475             NaN               NaN                   NaN
#
#      PLAYER3_TEAM_ABBREVIATION
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 12                         NaN
# 28                         NaN
# 40                         NaN
# 46                         NaN
# 49                         NaN
# 67                         NaN
# 70                         NaN
# 75                         NaN
# 92                         NaN
# 97                         NaN
# 119                        NaN
# 121                        NaN
# 134                        NaN
# 154                        NaN
# 161                        NaN
# 176                        NaN
# 190                        NaN
# 206                        NaN
# 240                        NaN
# 248                        NaN
# 260                        NaN
# 261                        NaN
# 265                        NaN
# 268                        NaN
# 279                        NaN
# 282                        NaN
# 284                        NaN
# ..                         ...
# 134                        NaN
# 136                        NaN
# 179                        NaN
# 200                        NaN
# 217                        NaN
# 221                        NaN
# 228                        NaN
# 241                        NaN
# 242                        NaN
# 249                        NaN
# 260                        NaN
# 261                        NaN
# 262                        NaN
# 267                        NaN
# 268                        NaN
# 279                        NaN
# 302                        NaN
# 321                        NaN
# 336                        NaN
# 338                        NaN
# 343                        NaN
# 364                        NaN
# 373                        NaN
# 387                        NaN
# 413                        NaN
# 416                        NaN
# 454                        NaN
# 471                        NaN
# 472                        NaN
# 475                        NaN
#
# [84 rows x 33 columns]

# %%
# for each assist event ....
print("Starting unparsed pass dataset: "+ str(len(AST_df)))
CleanData_df = pd.DataFrame(columns=['SportVU eventNum', 'SportVUEventIndex', 'time ball passed', 'time ball caught', 'passInHull', 'receiverinHull','SportVUMomentIndex', 'reversedIndexBallCaught', 'PBPTime' , 'PBP_HOMEDESCRIPTION' , 'PBP_VISITORDESCRIPTION' ])

if(not curPath.endswith('SportVU_JSON_Data')):
    curPath = os.getcwd()
    print curPath
    strIndex=curPath.index('\\JupyterNotebooks\\')
    curPath = curPath[:(strIndex+18)]+'SportVU_JSON_Data\\'
    os.chdir(curPath)
print curPath
#SportVU_JSON_Rootpath = "C:\Users\jchin\Documents\GitHub\Data Mining Course\DataMining-Project-Folder\JupyterNotebooks\SportVU_JSON_Data\\"
#print SportVU_JSON_Rootpath+str(gameid)+".json"
gameid_prev = 0;
for index, ast in AST_df.iterrows():
    gameid = ast["GAME_ID"]    #game id from PBP
    eventNumPBP = ast["EVENTNUM"] #eventNumber for the play
    gametimePBP = ast["PCTIMESTRING"]  #game time for the play
    quarterPBP = int(ast["PERIOD"])
    #getPBPInfo(gameid,eventNumPBP)
    print("prevGameID:"+str(gameid_prev)+", currentlyAnalyzingGameID:"+str(gameid))
    print("PBPEventNum:"+str(eventNumPBP)+", gametimePBP:"+str(gametimePBP))
    #check if SportVU json data is already opened for this PBP play
    if(gameid_prev != gameid):
        #open raw JSON SportVU data using game id from assist
        with open(curPath+"00"+str(gameid)+".json") as data_file:    
            rawSportVUData = json.load(data_file)
            json_normalize(rawSportVUData['events'])
        gameid_prev = gameid
    
    #get the correct eventNum (returned as long) in SportsVU
    eventNumSportsVU = findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, eventNumPBP)
    if(eventNumSportsVU is None):
        print("Could not find eventNum in SportsVU")
        continue
    
    
    print("Correct SportVU eventNum: "+str(eventNumSportsVU))
    #extract SportsVU movements for that eventNum
    
    rawpossessionSportsVU, SportVUEventIndex = MomentsfromEventNum(rawSportVUData, int(eventNumSportsVU))
    
    #for analyzing AST only...
    receiverID = int(ast['PLAYER1_ID'])
    passerID = int(ast['PLAYER2_ID'])
    teamID = int(ast['PLAYER1_TEAM_ID'])
    #PBPTime = str(ast['PCTIMESTRING'])
    PBP_HOMEDESCRIPTION = str(ast['HOMEDESCRIPTION']) 
    PBP_VISITORDESCRIPTION = str(ast['VISITORDESCRIPTION'])
    
                     
    #get catch details (who was the passer, receiver, and when caught/passed)
    timeBallReleased, indexBallReleased, timeBallCaught, indexBallCaught, timeBallPassed, indexBallPassed, receiverPosAtPass, receiverPosAtCaught, passerPosAtPass , SportVUMomentIndex= getCatchEventDetails(receiverID, passerID, gametimePBP, rawpossessionSportsVU)
    
    if(timeBallReleased is None):
        print("Could not find time for when ball was passed")
        continue
    
    #hull details
    momentsReversed = rawpossessionSportsVU[::-1]
    hull, np_points = getHull(momentsReversed[indexBallCaught], teamID)
                     
    #passer in hull?
    
    passerInHull = isInHull(hull,np_points, passerPosAtPass[0] ,passerPosAtPass[1])
                     
    #receiver in hull?
    receiverInHull = isInHull(hull,np_points, receiverPosAtPass[0] ,receiverPosAtPass[1])
    
    
    #PBPTime , PBP_HOMEDESCRIPTION , PBP_VISITORDESCRIPTION = getPBPInfo("00"+str(gameid), eventNumPBP) 
    CleanData_df.loc[len(CleanData_df.index)] = [eventNumSportsVU , SportVUEventIndex, timeBallPassed, timeBallCaught, passerInHull, receiverInHull, SportVUMomentIndex , indexBallCaught, gametimePBP , PBP_HOMEDESCRIPTION , PBP_VISITORDESCRIPTION ]
    

CleanData_df.to_csv("CleanedData.csv", sep='\t')
# Out:
# Starting unparsed pass dataset: 84
# D:\DataMining-NBA-Repo\JupyterNotebooks\pbp-csv
# D:\DataMining-NBA-Repo\JupyterNotebooks\SportVU_JSON_Data\
# prevGameID:0, currentlyAnalyzingGameID:21500001
# PBPEventNum:5, gametimePBP:11:21
# Finding correct SportVU eventNum for gameid:0021500001
# 681
# Currently checking eventNumPBP: 5
# sportVU Index for the eventNumPBP: 4
# Correct SportVU eventNum: 5
# sportVU Index for the eventNumPBP: 4
# 681
# num of moments: 623
# starting at time: 681.02
# receiver holding ball: 9.62
# receiver holding ball: 9.66
# receiver holding ball: 9.71
# 11:23
# receiver just caught ball: 12.34 received reversed index219
# 0:12
# receiver just caught ball: 12.38 received reversed index220
# 0:12
# receiver just caught ball: 12.42 received reversed index221
# 0:12
# 11:26
# passer just passed ball: 12.76 passed reversed index229
# passer just passed ball: 12.8 passed reversed index230
# player PASSED ball at 12.84
# 11:26
# [[21.95424, 37.78269], [22.02161, 7.38196], [11.36992, 18.75068], [10.1838, 46.8024], [25.14954, 18.85151]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:6, gametimePBP:11:00
# Finding correct SportVU eventNum for gameid:0021500001
# 660
# Currently checking eventNumPBP: 6
# sportVU Index for the eventNumPBP: 5
# Correct SportVU eventNum: 6
# sportVU Index for the eventNumPBP: 5
# 660
# num of moments: 675
# starting at time: 660.02
# receiver holding ball: 7.72
# receiver holding ball: 7.76
# receiver holding ball: 7.8
# 11:2
# receiver just caught ball: 8.64 received reversed index180
# 0:8
# receiver just caught ball: 8.68 received reversed index181
# 0:8
# receiver just caught ball: 8.72 received reversed index182
# 0:8
# 11:3
# passer just passed ball: 12.72 passed reversed index282
# passer just passed ball: 12.76 passed reversed index283
# player PASSED ball at 12.8
# 11:7
# [[62.74583, 35.42916], [84.53339, 32.44188], [88.46462, 14.11529], [59.24615, 16.67146], [78.0802, 2.76374]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:7, gametimePBP:10:44
# Finding correct SportVU eventNum for gameid:0021500001
# 644
# Currently checking eventNumPBP: 7
# sportVU Index for the eventNumPBP: 6
# Correct SportVU eventNum: 7
# sportVU Index for the eventNumPBP: 6
# 644
# num of moments: 525
# starting at time: 644.03
# receiver holding ball: 13.69
# receiver holding ball: 13.73
# receiver holding ball: 13.76
# 10:47
# receiver just caught ball: 14.96 received reversed index196
# 0:14
# receiver just caught ball: 15.07 received reversed index199
# 0:15
# receiver just caught ball: 15.1 received reversed index200
# 0:15
# 10:49
# passer just passed ball: 16.83 passed reversed index249
# passer just passed ball: 16.87 passed reversed index250
# player PASSED ball at 16.9
# 10:51
# [[20.87368, 40.0393], [31.8344, 17.03858], [7.01221, 1.93252], [13.64037, 42.92275], [23.88321, 18.28875]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:13, gametimePBP:10:01
# Finding correct SportVU eventNum for gameid:0021500001
# 601
# Currently checking eventNumPBP: 13
# sportVU Index for the eventNumPBP: 11
# Correct SportVU eventNum: 13
# sportVU Index for the eventNumPBP: 11
# 601
# num of moments: 575
# starting at time: 601.02
# receiver holding ball: 14.98
# receiver holding ball: 15.02
# receiver holding ball: 15.06
# 10:4
# receiver just caught ball: 16.14 received reversed index368
# 0:16
# receiver just caught ball: 16.18 received reversed index369
# 0:16
# receiver just caught ball: 17.26 received reversed index396
# 0:17
# 10:6
# passer just passed ball: 17.82 passed reversed index410
# passer just passed ball: 17.86 passed reversed index411
# player PASSED ball at 17.9
# 10:7
# [[83.40677, 2.41038], [81.77704, 32.24516], [63.44107, 25.47671], [65.54236, 7.86335], [61.01206, 40.33203]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:33, gametimePBP:8:11
# Finding correct SportVU eventNum for gameid:0021500001
# 491
# Currently checking eventNumPBP: 33
# sportVU Index for the eventNumPBP: 28
# Correct SportVU eventNum: 33
# sportVU Index for the eventNumPBP: 28
# 491
# num of moments: 725
# starting at time: 491.03
# receiver holding ball: 4.28
# receiver holding ball: 4.33
# receiver holding ball: 4.37
# 8:12
# receiver just caught ball: 4.63 received reversed index153
# 0:4
# receiver just caught ball: 4.66 received reversed index154
# 0:4
# receiver just caught ball: 4.7 received reversed index155
# 0:4
# 8:13
# passer just passed ball: 5.37 passed reversed index175
# passer just passed ball: 5.41 passed reversed index176
# player PASSED ball at 5.44
# 8:13
# [[31.91859, 27.83911], [28.11885, 6.98873], [10.00508, 1.97758], [17.14182, 47.3291], [8.94086, 25.98631]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:47, gametimePBP:6:48
# Finding correct SportVU eventNum for gameid:0021500001
# 408
# Currently checking eventNumPBP: 47
# sportVU Index for the eventNumPBP: 40
# Correct SportVU eventNum: 47
# sportVU Index for the eventNumPBP: 40
# 408
# num of moments: 651
# starting at time: 408.01
# receiver holding ball: 8.87
# receiver holding ball: 8.91
# receiver holding ball: 8.95
# 6:50
# receiver just caught ball: 9.75 received reversed index186
# 0:9
# receiver just caught ball: 9.79 received reversed index187
# 0:9
# receiver just caught ball: 9.83 received reversed index188
# 0:9
# 6:51
# passer just passed ball: 10.35 passed reversed index201
# passer just passed ball: 10.39 passed reversed index202
# player PASSED ball at 10.43
# 6:52
# [[31.24948, 21.61545], [11.5381, 47.04498], [11.81085, 9.92699], [27.27022, 41.18246], [12.05395, 33.88083]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:55, gametimePBP:6:30
# Finding correct SportVU eventNum for gameid:0021500001
# 390
# Currently checking eventNumPBP: 55
# sportVU Index for the eventNumPBP: 46
# Correct SportVU eventNum: 55
# sportVU Index for the eventNumPBP: 46
# 390
# num of moments: 425
# starting at time: 390.03
# receiver holding ball: 16.29
# receiver holding ball: 16.34
# receiver holding ball: 16.38
# 6:32
# receiver just caught ball: 18.02 received reversed index196
# 0:18
# receiver just caught ball: 18.06 received reversed index197
# 0:18
# receiver just caught ball: 18.11 received reversed index198
# 0:18
# 6:33
# passer just passed ball: 18.71 passed reversed index212
# passer just passed ball: 18.75 passed reversed index213
# player PASSED ball at 18.8
# 6:34
# [[23.46911, 38.13505], [28.63182, 17.03232], [15.92967, 13.41816], [3.97385, 45.24821], [26.40035, 34.17695]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:58, gametimePBP:5:57
# Finding correct SportVU eventNum for gameid:0021500001
# 357
# Currently checking eventNumPBP: 58
# sportVU Index for the eventNumPBP: 49
# Correct SportVU eventNum: 58
# sportVU Index for the eventNumPBP: 49
# 357
# num of moments: 325
# starting at time: 357.02
# receiver holding ball: 18.79
# receiver holding ball: 18.82
# receiver holding ball: 18.86
# 5:59
# receiver just caught ball: 19.42 received reversed index193
# 0:19
# receiver just caught ball: 19.46 received reversed index194
# 0:19
# receiver just caught ball: 19.49 received reversed index195
# 0:19
# 6:0
# passer just passed ball: 20.05 passed reversed index211
# passer just passed ball: 20.09 passed reversed index212
# player PASSED ball at 20.12
# 6:0
# [[29.72826, 39.13291], [25.03368, 13.34735], [35.56412, 24.53977], [13.22803, 47.68306], [6.6648, 24.61115]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:77, gametimePBP:4:23
# Finding correct SportVU eventNum for gameid:0021500001
# 263
# Currently checking eventNumPBP: 77
# sportVU Index for the eventNumPBP: 67
# Correct SportVU eventNum: 77
# sportVU Index for the eventNumPBP: 67
# 263
# num of moments: 338
# starting at time: 263.03
# receiver holding ball: 10.73
# receiver holding ball: 10.76
# receiver holding ball: 10.8
# 4:24
# receiver just caught ball: 11.85 received reversed index69
# 0:11
# receiver just caught ball: 11.89 received reversed index70
# 0:11
# receiver just caught ball: 12.19 received reversed index78
# 0:12
# 4:25
# passer just passed ball: 13.91 passed reversed index124
# passer just passed ball: 13.95 passed reversed index125
# player PASSED ball at 13.98
# 4:27
# [[20.754, 43.57031], [16.7744, 40.60485], [32.47686, 10.86016], [16.71312, 17.20088], [6.47049, 1.16551]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:81, gametimePBP:4:13
# Finding correct SportVU eventNum for gameid:0021500001
# 253
# Currently checking eventNumPBP: 81
# sportVU Index for the eventNumPBP: 70
# Correct SportVU eventNum: 81
# sportVU Index for the eventNumPBP: 70
# 253
# num of moments: 375
# starting at time: 253.02
# receiver holding ball: 15.75
# receiver holding ball: 15.8
# receiver holding ball: 15.84
# 4:15
# receiver just caught ball: 16.88 received reversed index190
# 0:16
# receiver just caught ball: 16.92 received reversed index191
# 0:16
# receiver just caught ball: 16.97 received reversed index192
# 0:16
# 4:16
# passer just passed ball: 17.19 passed reversed index197
# passer just passed ball: 17.24 passed reversed index198
# player PASSED ball at 17.28
# 4:17
# [[87.45365, 40.45392], [75.22081, 3.2701], [63.38535, 19.58278], [89.18566, 6.52357], [78.82291, 35.34637]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:86, gametimePBP:3:33
# Finding correct SportVU eventNum for gameid:0021500001
# 213
# Currently checking eventNumPBP: 86
# sportVU Index for the eventNumPBP: 75
# Correct SportVU eventNum: 86
# sportVU Index for the eventNumPBP: 75
# 213
# num of moments: 350
# starting at time: 213.03
# receiver holding ball: 15.79
# receiver holding ball: 15.82
# receiver holding ball: 15.86
# 3:35
# receiver just caught ball: 16.31 received reversed index177
# 0:16
# receiver just caught ball: 16.35 received reversed index178
# 0:16
# receiver just caught ball: 16.39 received reversed index179
# 0:16
# 3:36
# passer just passed ball: 16.72 passed reversed index188
# passer just passed ball: 16.76 passed reversed index189
# player PASSED ball at 16.8
# 3:36
# [[23.78779, 13.01622], [25.90012, 44.07486], [9.48595, 48.15031], [10.00203, 23.95168], [9.33639, 1.17167]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:105, gametimePBP:1:47
# Finding correct SportVU eventNum for gameid:0021500001
# 107
# Currently checking eventNumPBP: 105
# sportVU Index for the eventNumPBP: 92
# Correct SportVU eventNum: 105
# sportVU Index for the eventNumPBP: 92
# 107
# num of moments: 425
# starting at time: 107.01
# receiver holding ball: 11.66
# receiver holding ball: 11.7
# receiver holding ball: 11.74
# 1:49
# receiver just caught ball: 12.94 received reversed index189
# 0:12
# receiver just caught ball: 12.98 received reversed index190
# 0:12
# receiver just caught ball: 13.02 received reversed index191
# 0:13
# 1:50
# passer just passed ball: 14.98 passed reversed index240
# passer just passed ball: 15.02 passed reversed index241
# player PASSED ball at 15.06
# 1:52
# [[75.68995, 24.78592], [89.00367, 6.19983], [70.92586, 29.46816], [59.95027, 14.65658], [78.11457, 39.95304]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:110, gametimePBP:0:32
# Finding correct SportVU eventNum for gameid:0021500001
# 32
# Currently checking eventNumPBP: 110
# sportVU Index for the eventNumPBP: 97
# Could not find eventNum in SportsVU
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:132, gametimePBP:10:31
# Finding correct SportVU eventNum for gameid:0021500001
# 631
# Currently checking eventNumPBP: 132
# sportVU Index for the eventNumPBP: 118
# Correct SportVU eventNum: 132
# sportVU Index for the eventNumPBP: 118
# 631
# num of moments: 323
# starting at time: 631.0
# receiver holding ball: 18.03
# receiver holding ball: 18.07
# receiver holding ball: 18.11
# 10:33
# receiver just caught ball: 18.97 received reversed index195
# 0:18
# receiver just caught ball: 19.01 received reversed index196
# 0:19
# receiver just caught ball: 19.05 received reversed index197
# 0:19
# 10:34
# passer just passed ball: 19.52 passed reversed index209
# passer just passed ball: 19.56 passed reversed index210
# player PASSED ball at 19.59
# 10:34
# [[69.59411, 42.7731], [63.91624, 18.45841], [88.29483, 29.93777], [84.26585, 23.09698], [81.91848, 4.19483]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:137, gametimePBP:10:20
# Finding correct SportVU eventNum for gameid:0021500001
# 620
# Currently checking eventNumPBP: 137
# sportVU Index for the eventNumPBP: 120
# Correct SportVU eventNum: 137
# sportVU Index for the eventNumPBP: 120
# 620
# num of moments: 300
# starting at time: 620.01
# receiver holding ball: 19.08
# receiver holding ball: 19.13
# receiver holding ball: 19.19
# 10:22
# receiver just caught ball: 20.0 received reversed index193
# 0:20
# receiver just caught ball: 20.0 received reversed index194
# 0:20
# receiver just caught ball: 20.0 received reversed index195
# 0:20
# 10:23
# passer just passed ball: 20.0 passed reversed index209
# passer just passed ball: 20.0 passed reversed index210
# player PASSED ball at 20.0
# 10:23
# [[6.70907, 9.61083], [27.60639, 24.49243], [16.66959, 22.70856], [3.67602, 37.88844], [25.6191, -1.40993]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:150, gametimePBP:8:48
# Finding correct SportVU eventNum for gameid:0021500001
# 528
# Currently checking eventNumPBP: 150
# sportVU Index for the eventNumPBP: 133
# Correct SportVU eventNum: 150
# sportVU Index for the eventNumPBP: 133
# 528
# num of moments: 525
# starting at time: 528.0
# receiver holding ball: 13.18
# receiver holding ball: 13.22
# receiver holding ball: 13.26
# 8:50
# receiver just caught ball: 14.52 received reversed index205
# 0:14
# receiver just caught ball: 14.56 received reversed index206
# 0:14
# receiver just caught ball: 14.6 received reversed index207
# 0:14
# 8:52
# passer just passed ball: 15.81 passed reversed index236
# passer just passed ball: 15.85 passed reversed index237
# player PASSED ball at 15.89
# 8:53
# [[17.91113, 23.92353], [26.94172, 11.82557], [5.559, 31.51356], [28.67217, 35.48529], [3.67664, 3.34369]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:172, gametimePBP:7:06
# Finding correct SportVU eventNum for gameid:0021500001
# 426
# Currently checking eventNumPBP: 172
# sportVU Index for the eventNumPBP: 153
# Correct SportVU eventNum: 172
# sportVU Index for the eventNumPBP: 153
# 426
# num of moments: 575
# starting at time: 426.0
# receiver holding ball: 13.23
# receiver holding ball: 13.26
# receiver holding ball: 13.3
# 7:8
# receiver just caught ball: 13.94 received reversed index211
# 0:13
# receiver just caught ball: 13.97 received reversed index212
# 0:13
# receiver just caught ball: 14.0 received reversed index213
# 0:14
# 7:9
# passer just passed ball: 14.68 passed reversed index235
# passer just passed ball: 14.71 passed reversed index236
# player PASSED ball at 14.74
# 7:10
# [[31.77686, 16.72341], [24.96715, 40.99509], [7.23263, 2.00196], [14.51203, 17.24609], [8.59926, 44.02305]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:180, gametimePBP:6:05
# Finding correct SportVU eventNum for gameid:0021500001
# 365
# Currently checking eventNumPBP: 180
# sportVU Index for the eventNumPBP: 160
# Correct SportVU eventNum: 180
# sportVU Index for the eventNumPBP: 160
# 365
# num of moments: 300
# starting at time: 365.0
# receiver holding ball: 22.5
# receiver holding ball: 22.39
# receiver holding ball: 22.28
# 6:7
# receiver just caught ball: 20.47 received reversed index194
# 0:20
# receiver just caught ball: 20.56 received reversed index195
# 0:20
# receiver just caught ball: 20.64 received reversed index196
# 0:20
# 6:8
# passer just passed ball: 22.85 passed reversed index221
# passer just passed ball: 23.12 passed reversed index224
# player PASSED ball at 23.21
# 6:9
# [[23.63358, 15.33535], [51.78625, 23.30847], [38.19494, 16.69325], [67.18494, 24.87988], [45.61834, 37.11054]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:197, gametimePBP:4:35
# Finding correct SportVU eventNum for gameid:0021500001
# 275
# Currently checking eventNumPBP: 197
# sportVU Index for the eventNumPBP: 176
# Correct SportVU eventNum: 197
# sportVU Index for the eventNumPBP: 176
# 275
# num of moments: 445
# starting at time: 275.02
# receiver holding ball: 18.28
# receiver holding ball: 18.32
# receiver holding ball: 18.36
# 4:36
# receiver just caught ball: 19.36 received reversed index204
# 0:19
# receiver just caught ball: 19.4 received reversed index205
# 0:19
# receiver just caught ball: 19.44 received reversed index206
# 0:19
# 4:37
# passer just passed ball: 19.89 passed reversed index217
# passer just passed ball: 19.93 passed reversed index218
# player PASSED ball at 19.97
# 4:38
# [[23.17638, 22.16846], [8.15009, 47.75215], [28.34561, 32.50695], [27.61542, 10.26846], [13.73442, 16.44546]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:214, gametimePBP:2:50
# Finding correct SportVU eventNum for gameid:0021500001
# 170
# Currently checking eventNumPBP: 214
# sportVU Index for the eventNumPBP: 192
# Correct SportVU eventNum: 214
# sportVU Index for the eventNumPBP: 192
# 170
# num of moments: 600
# starting at time: 170.03
# receiver holding ball: 7.77
# receiver holding ball: 7.8
# receiver holding ball: 7.83
# 2:53
# receiver just caught ball: 8.16 received reversed index194
# 0:8
# receiver just caught ball: 8.2 received reversed index195
# 0:8
# receiver just caught ball: 8.23 received reversed index196
# 0:8
# 2:53
# passer just passed ball: 8.89 passed reversed index216
# passer just passed ball: 8.92 passed reversed index217
# player PASSED ball at 8.95
# 2:54
# [[9.92873, 24.31069], [6.18903, 33.42229], [33.38271, 21.68221], [18.59057, 46.18298], [27.44137, 33.57496]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:232, gametimePBP:0:55
# Finding correct SportVU eventNum for gameid:0021500001
# 55
# Currently checking eventNumPBP: 232
# sportVU Index for the eventNumPBP: 208
# Correct SportVU eventNum: 232
# sportVU Index for the eventNumPBP: 208
# 55
# num of moments: 225
# starting at time: 55.0
# receiver holding ball: 24.0
# receiver holding ball: 24.0
# receiver holding ball: 24.0
# 0:56
# receiver just caught ball: 20.73 received reversed index72
# 0:20
# receiver just caught ball: 20.77 received reversed index73
# 0:20
# receiver just caught ball: 20.84 received reversed index75
# 0:20
# 0:56
# passer just passed ball: 23.69 passed reversed index151
# passer just passed ball: 23.73 passed reversed index152
# player PASSED ball at 23.76
# 0:59
# [[57.72877, 12.33059], [78.87161, 37.93776], [5.75495, 23.11155], [81.9691, 18.43502], [33.90599, 36.3838]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:269, gametimePBP:8:37
# Finding correct SportVU eventNum for gameid:0021500001
# 517
# Currently checking eventNumPBP: 269
# sportVU Index for the eventNumPBP: 243
# Correct SportVU eventNum: 269
# sportVU Index for the eventNumPBP: 243
# 517
# num of moments: 514
# starting at time: 517.01
# receiver holding ball: 8.91
# receiver holding ball: 8.95
# receiver holding ball: 8.99
# 8:37
# receiver just caught ball: 9.56 received reversed index33
# 0:9
# receiver just caught ball: 9.6 received reversed index34
# 0:9
# receiver just caught ball: 9.64 received reversed index35
# 0:9
# 8:37
# passer just passed ball: 11.27 passed reversed index75
# passer just passed ball: 11.31 passed reversed index76
# player PASSED ball at 11.35
# 8:39
# [[64.3194, 28.5193], [64.86101, 34.92905], [82.38713, 42.66825], [70.91426, 12.76705], [77.18193, 10.15939]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:282, gametimePBP:7:42
# Finding correct SportVU eventNum for gameid:0021500001
# 462
# Currently checking eventNumPBP: 282
# sportVU Index for the eventNumPBP: 251
# Correct SportVU eventNum: 282
# sportVU Index for the eventNumPBP: 251
# 462
# num of moments: 550
# starting at time: 462.01
# receiver holding ball: 11.5
# receiver holding ball: 11.54
# receiver holding ball: 11.57
# 7:44
# receiver just caught ball: 12.29 received reversed index190
# 0:12
# receiver just caught ball: 12.32 received reversed index191
# 0:12
# receiver just caught ball: 12.35 received reversed index192
# 0:12
# 7:45
# passer just passed ball: 12.93 passed reversed index209
# passer just passed ball: 12.96 passed reversed index210
# player PASSED ball at 13.0
# 7:46
# [[26.81409, 35.12599], [21.34563, 15.06962], [26.59504, 32.90914], [9.10581, 47.36288], [1.38991, 17.21605]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:294, gametimePBP:5:55
# Finding correct SportVU eventNum for gameid:0021500001
# 355
# Currently checking eventNumPBP: 294
# sportVU Index for the eventNumPBP: 263
# Correct SportVU eventNum: 294
# sportVU Index for the eventNumPBP: 263
# 355
# num of moments: 775
# starting at time: 355.0
# receiver holding ball: 6.06
# receiver holding ball: 6.1
# receiver holding ball: 6.14
# 5:57
# receiver just caught ball: 7.15 received reversed index230
# 0:7
# receiver just caught ball: 7.19 received reversed index231
# 0:7
# receiver just caught ball: 7.23 received reversed index232
# 0:7
# 5:58
# passer just passed ball: 7.63 passed reversed index242
# passer just passed ball: 7.67 passed reversed index243
# player PASSED ball at 7.71
# 5:58
# [[10.54947, 1.35476], [29.49716, 35.54277], [5.45208, 47.61477], [17.35004, 26.94017], [30.41778, 18.07377]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:295, gametimePBP:5:39
# Finding correct SportVU eventNum for gameid:0021500001
# 339
# Currently checking eventNumPBP: 295
# sportVU Index for the eventNumPBP: 264
# Correct SportVU eventNum: 295
# sportVU Index for the eventNumPBP: 264
# 339
# num of moments: 500
# starting at time: 339.0
# receiver holding ball: 16.83
# receiver holding ball: 16.86
# receiver holding ball: 16.89
# 5:41
# receiver just caught ball: 17.53 received reversed index192
# 0:17
# receiver just caught ball: 17.56 received reversed index193
# 0:17
# receiver just caught ball: 17.59 received reversed index194
# 0:17
# 5:42
# passer just passed ball: 18.26 passed reversed index217
# passer just passed ball: 18.29 passed reversed index218
# player PASSED ball at 18.32
# 5:43
# [[69.59429, 19.07285], [60.4465, 29.09848], [82.67534, 48.84319], [84.92649, 1.41778], [77.64118, 32.7275]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:301, gametimePBP:5:13
# Finding correct SportVU eventNum for gameid:0021500001
# 313
# Currently checking eventNumPBP: 301
# sportVU Index for the eventNumPBP: 268
# Correct SportVU eventNum: 301
# sportVU Index for the eventNumPBP: 268
# 313
# num of moments: 600
# starting at time: 313.0
# receiver holding ball: 7.43
# receiver holding ball: 7.48
# receiver holding ball: 7.52
# 5:15
# receiver just caught ball: 8.83 received reversed index209
# 0:8
# receiver just caught ball: 8.87 received reversed index210
# 0:8
# receiver just caught ball: 8.91 received reversed index211
# 0:8
# 5:16
# passer just passed ball: 9.42 passed reversed index223
# passer just passed ball: 9.46 passed reversed index224
# player PASSED ball at 9.51
# 5:17
# [[76.04417, 43.07073], [59.94092, 33.48695], [80.8659, 24.66114], [68.49155, 7.60574], [88.62307, 18.26191]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:304, gametimePBP:4:50
# Finding correct SportVU eventNum for gameid:0021500001
# 290
# Currently checking eventNumPBP: 304
# sportVU Index for the eventNumPBP: 271
# Correct SportVU eventNum: 304
# sportVU Index for the eventNumPBP: 271
# 290
# num of moments: 300
# starting at time: 290.01
# receiver holding ball: 18.56
# receiver holding ball: 18.59
# receiver holding ball: 18.62
# 4:52
# receiver just caught ball: 19.35 received reversed index187
# 0:19
# receiver just caught ball: 19.38 received reversed index188
# 0:19
# receiver just caught ball: 19.41 received reversed index189
# 0:19
# 4:53
# passer just passed ball: 19.88 passed reversed index204
# passer just passed ball: 19.91 passed reversed index205
# player PASSED ball at 19.94
# 4:53
# [[88.52005, 32.20671], [62.40745, 23.08841], [70.91732, 42.22178], [72.55847, 2.82061], [85.37371, 22.66411]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:317, gametimePBP:4:10
# Finding correct SportVU eventNum for gameid:0021500001
# 250
# Currently checking eventNumPBP: 317
# sportVU Index for the eventNumPBP: 282
# Correct SportVU eventNum: 317
# sportVU Index for the eventNumPBP: 282
# 250
# num of moments: 675
# starting at time: 250.02
# receiver holding ball: 24.0
# receiver holding ball: 24.0
# receiver holding ball: 2.7
# 4:11
# receiver just caught ball: 3.97 received reversed index170
# 0:3
# receiver just caught ball: 4.05 received reversed index172
# 0:4
# receiver just caught ball: 4.13 received reversed index174
# 0:4
# 4:13
# passer just passed ball: 4.57 passed reversed index185
# passer just passed ball: 4.61 passed reversed index186
# player PASSED ball at 4.65
# 4:13
# [[6.45919, 7.73276], [5.75818, 20.76052], [7.96214, 29.4852], [11.55516, 47.01548], [30.15233, 34.49179]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:321, gametimePBP:3:32
# Finding correct SportVU eventNum for gameid:0021500001
# 212
# Currently checking eventNumPBP: 321
# sportVU Index for the eventNumPBP: 286
# Correct SportVU eventNum: 321
# sportVU Index for the eventNumPBP: 286
# 212
# num of moments: 575
# starting at time: 212.02
# receiver holding ball: 7.83
# receiver holding ball: 7.87
# receiver holding ball: 7.91
# 3:34
# receiver just caught ball: 7.99 received reversed index184
# 0:7
# receiver just caught ball: 8.83 received reversed index206
# 0:8
# receiver just caught ball: 8.86 received reversed index207
# 0:8
# 3:35
# passer just passed ball: 9.1 passed reversed index213
# passer just passed ball: 9.13 passed reversed index214
# player PASSED ball at 9.17
# 3:36
# [[23.45015, 28.62094], [13.38828, 12.05528], [9.37026, 33.82061], [8.40475, 1.88339], [27.49722, 37.50602]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:324, gametimePBP:2:52
# Finding correct SportVU eventNum for gameid:0021500001
# 172
# Currently checking eventNumPBP: 324
# sportVU Index for the eventNumPBP: 288
# Correct SportVU eventNum: 324
# sportVU Index for the eventNumPBP: 288
# 172
# num of moments: 400
# starting at time: 172.01
# receiver holding ball: 19.13
# receiver holding ball: 19.17
# receiver holding ball: 19.21
# 2:54
# receiver just caught ball: 20.05 received reversed index184
# 0:20
# receiver just caught ball: 20.09 received reversed index185
# 0:20
# receiver just caught ball: 20.13 received reversed index186
# 0:20
# 2:55
# passer just passed ball: 21.29 passed reversed index215
# passer just passed ball: 21.33 passed reversed index216
# player PASSED ball at 21.37
# 2:56
# [[8.63596, 27.32824], [26.95012, 43.93908], [36.67293, 27.96857], [33.27668, 7.29987], [21.16121, 20.02674]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:341, gametimePBP:1:56
# Finding correct SportVU eventNum for gameid:0021500001
# 116
# Currently checking eventNumPBP: 341
# sportVU Index for the eventNumPBP: 300
# Correct SportVU eventNum: 341
# sportVU Index for the eventNumPBP: 300
# 116
# num of moments: 739
# starting at time: 116.02
# receiver holding ball: 6.8
# receiver holding ball: 6.84
# receiver holding ball: 6.88
# 1:58
# receiver just caught ball: 7.8 received reversed index208
# 0:7
# receiver just caught ball: 7.84 received reversed index209
# 0:7
# receiver just caught ball: 7.88 received reversed index210
# 0:7
# 1:59
# passer just passed ball: 8.56 passed reversed index227
# passer just passed ball: 8.59 passed reversed index228
# player PASSED ball at 8.63
# 2:0
# [[2.68571, 29.84853], [7.04586, 16.92538], [29.98861, 32.15106], [27.5696, 9.61344], [4.89065, 3.91366]]
# prevGameID:21500001, currentlyAnalyzingGameID:21500001
# PBPEventNum:350, gametimePBP:0:50
# Finding correct SportVU eventNum for gameid:0021500001
# 50
# Currently checking eventNumPBP: 350
# sportVU Index for the eventNumPBP: 309
# Currently checking eventNumPBP: 351
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-6b9ad4753b92> in <module>()
#      30
#      31     #get the correct eventNum (returned as long) in SportsVU
# ---> 32     eventNumSportsVU = findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, eventNumPBP)
#      33     if(eventNumSportsVU is None):
#      34         print("Could not find eventNum in SportsVU")
#
# <ipython-input-44-3250fd4298d8> in findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, approxEventNumPBP)
#       8     while (found == False):
#       9         print("Currently checking eventNumPBP: "+str(approxEventNumPBP))
# ---> 10         moments, SportVUEventIndex = MomentsfromEventNum(rawSportVUData, approxEventNumPBP)
#      11         if (moments is None or len(moments) == 0):
#      12             return None
#
# TypeError: 'NoneType' object is not iterable

# %%
#for i, row in events_queried.iterrows():
for i in range(events_queried.shape[0]):
    #extract the row from events dataframe
    extractedRow = events_queried.iloc[i]
    print extractedRow
    #movement_events_df.append(extractedRow,ignore_index=True)
    movement_events_df = movement_events_df.append(pd.DataFrame(extractedRow), ignore_index=True)
    #movement_events_df = pd.concat([movement_events_df, row], axis=1)

# %%
getPBPInfo(21500001,5)
# Out:
# D:\DataMining-NBA-Repo\JupyterNotebooks\SportVU_JSON_Data
# D:\DataMining-NBA-Repo\JupyterNotebooks\\pbp-csv
# 5    11:21
# Name: PCTIMESTRING, dtype: object
# 5    NaN
# Name: HOMEDESCRIPTION, dtype: object
# 5    Marc Morris 13' Step Back Jump Shot (2 PTS) (D...
# Name: VISITORDESCRIPTION, dtype: object
