# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

#for importing files
import glob, os
import matplotlib.pyplot as plt
# %matplotlib inline


#Library for hull calculation
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
from matplotlib.path import Path
from scipy.spatial import distance

# %% [markdown]
# ## Helper Methods

# %%
def SecsToGameTime(time):
    mins=(int(time)/60)
    secs=int(time)%60
    print (str(mins)+":"+str(secs))

# %%
def GameTimetoSeconds(time):
    mins, secs = time.split(":")
    timeSecs = int(mins)*60+int(secs)
    print(timeSecs)
    return timeSecs

# %% [markdown]
# #### Hull Calculation Helper Method

# %%
def getHull(moments, teamID):
    points = []
    
    if(moments[5][1][0] == teamID):
        for positions in moments[5][1:6]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    else:
        for positions in moments[5][6:11]:
            #print positions
            points.append([positions[2],positions[3]])
        print(points)
    
    np_points = np.asarray(points)
    np_points
    hull = ConvexHull(np_points)
    
    return hull,np_points

# %%
def distFromCentroid(hull, x,y):
        cx = np.mean(hull.points[hull.vertices,0])
        cy = np.mean(hull.points[hull.vertices,1])
        return ((x-cx)^2+(y-cy)^2)^.5

# %%
def isInHull(hull,np_points,x,y):
    #point in hull?
    hull_path = Path( np_points[hull.vertices] )
    isInPath = hull_path.contains_point((x,y))
    return (isInPath == True)

# %% [markdown]
# ### Given the game time (12:00) and eventNumber from the Play-by-play data for a recorded event, this method returns the correct eventNumber from the SportsVU data since they actually dont matchup.  This method converts the gametime into seconds (720s = 12:00) which is formatted in SportsVU.  It traverses up and down events until the gametime is within a selected eventNumber.

# %%
def findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, approxEventNumPBP):
    print("Finding correctSportVU eventNum gameid:"+rawSportVUData['gameid'])

    found = False;
    moments = None
    #convert gametimePBP (12:00) to seconds (720)
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    while (found == False):
        #print("Currently checking eventNumPBP: "+str(approxEventNumPBP))
        moments = MomentsfromEventNum(rawSportVUData, approxEventNumPBP)
        
        if len(moments) == 0:
            return None
        
        quarterSportVU = int(moments[0][0])
        #print("PBP quareter:"+str(quarterPBP)+"quartersportVU :"+str(quarterSportVU))
        #print("PBP gameclock:"+str(gameInSeconds)+" SportsVU moment clock:"+str(moments[0][2]))
        
        #check whether this EventNum moment is the correct time frame of the play from Play-by-play
        if(quarterPBP < quarterSportVU):
            approxEventNumPBP -= 1
        elif(quarterPBP > quarterSportVU):    
            approxEventNumPBP  += 1
        elif(int(moments[0][2]) > gameInSeconds and int(moments[len(moments)-1][2]) < gameInSeconds):
            found=True
        elif(moments[0][2] < gameInSeconds):
            approxEventNumPBP -= 1
        elif(moments[len(moments)-1][2] > gameInSeconds):
        # look ahead 1 event 
            approxEventNumPBP += 1
        else:
            return "error"
    #print("extracted event num "+ str(approxEventNumPBP))
    return approxEventNumPBP

# %%
def MomentsfromEventNum(eventsData, eventNum):
    return eventsData['events'][eventNum]["moments"]

# %% [markdown]
# ## Identify Moment of CATCH
#
# 1.  //sort events moment data from end time to beginning (reverse order)
# timeballReceived, locationballReceived = getReceive (recieverID, List[Moments])
#
# Each moment is taken every .25s, so the FIRST 8 moments (8 *.25 = 2 seconds) when the receiverID and ball are within (dist <= 1 ft), is when the ball was the moment before the ball was released.
#
# reset numCount = 0;
#
# Starting from this time, continue iterating through moments. If dist from receiver and ball >=1 ft, then this is time the ball was caught.
#
# ***separate calculation to check when the ball dist less than 1 ft for another teammate to determine if it was a pass in a certain amount of time (counted numCount)****
#
# 2.  Find "latest" instance when   distFrom ( Moment.Positions[0].x,Moment.Position[0].y , Moment.Position[ ??=playerID ].x , Moment.Position[ ??=playerID].y) <= 1ft )
#
#    return the timemilis ,  position[0].x , position[0].y

# %%
 def getCatchEventDetails(receiverID, passerID, gametimePBP, moments):
    momentsReversed = moments[::-1]

    index=0
    found = False
    gameInSeconds = GameTimetoSeconds(gametimePBP)
    print("num of moments: "+str(len(momentsReversed)))
    while (found == False):
        if(int(momentsReversed[index][2]) >=  gameInSeconds):
            found=True
        elif(int(momentsReversed[index][2]< gameInSeconds)):
            index += 1
        else:
            return "ERROR"
    
    print("starting at time: "+ str(momentsReversed[index][2]))
    
    #Found the index of the approx start of the event
    numCounts=0
    for i in range(index,len(momentsReversed)):
        if numCounts >= 3:
            timeBallReleased = momentsReversed[i][2]
            indexBallReleased = i
            break
        else:
            ball = momentsReversed[i][5][0]
            for positions in momentsReversed[i][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("receiver holding ball: " + str( momentsReversed[i][3]))
                numCounts += 1
                
    #count when ball is caught
    numCounts=0
    for j in range(indexBallReleased, len(momentsReversed)):
        if numCounts >= 3:
            timeBallCaught = momentsReversed[j][2]
            indexBallCaught = j
            
            #record position of receiver
            receiverMoment = momentsReversed[j][5]
            receiverPos = [k for k in receiverMoment if receiverID in k]
            
            reciever_pos_x = receiverPos[0][2]
            receiver_pos_y = receiverPos[0][3]
            receiverPosAtCaught = [reciever_pos_x, receiver_pos_y]
            
            break
        else:
            ball = momentsReversed[j][5][0]
            for positions in momentsReversed[j][5]:
                if positions[1] == receiverID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist >= 2:
                print("receiver just caught ball: " + str(momentsReversed[j][3])+" "+str(j))
                numCounts += 1
                
    #count when ball is passed
    numCounts=0
    for k in range(indexBallCaught, len(momentsReversed)):
        if numCounts >= 2:
            timeBallPassed = momentsReversed[k][2]
            indexBallPassed = k
            
               
            #record position of receiver
            receiverMoment = momentsReversed[k][5]
            receiverPos = [k for k in receiverMoment if receiverID in k]
            
            reciever_pos_x = receiverPos[0][2]
            receiver_pos_y = receiverPos[0][3]
            receiverPosAtPass = [reciever_pos_x ,receiver_pos_y]
        
            #record position of passer
            passerPos = [k for k in receiverMoment if passerID in k]
            
            passer_pos_x = passerPos[0][2]
            passer_pos_y = passerPos[0][3]
            passerPosAtPass = [passer_pos_x ,passer_pos_y]
            
            
            break
        else:
            print("aga")
            ball = momentsReversed[k][5][0]
            for positions in momentsReversed[k][5]:
                if positions[1] == passerID:
                    player_x = positions[2]
                    player_y = positions[3]
            dist = distance.euclidean([player_x,player_y],[ball[2],ball[3]])
            if dist <= 2:
                print("passer just passed ball: " +str(momentsReversed[k][3]))
                numCounts += 1
                
    SecsToGameTime(timeBallPassed)
    SecsToGameTime(timeBallCaught)
    SecsToGameTime(timeBallReleased)      
    return timeBallReleased, indexBallReleased, timeBallCaught, indexBallCaught, timeBallPassed, indexBallPassed, receiverPosAtPass, receiverPosAtCaught, passerPosAtPass

# %% [markdown]
# ### Extracts Assists, Bad Passes, Alley Oops from csvs in current directory and saves them into separate csv files

# %%
AST_df = pd.DataFrame()
BadPass_df = pd.DataFrame()
AlleyOop_df = pd.DataFrame()
curPath = os.getcwd()
print curPath
os.chdir(curPath+'\pbp-csv')
for pbpFile in glob.glob("*.csv"):
    print(pbpFile)
    #read file as df
    events_df = pd.read_csv(pbpFile)
    ASTList = events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("AST", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("AST", na = False )  ) ]
    BadPassList= events_df[( events_df['VISITORDESCRIPTION'].str.contains("Bad", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Bad", na = False )  ) ]
    AlleyOopList= events_df[events_df['EVENTMSGTYPE'].isin([1,2]) & ( events_df['VISITORDESCRIPTION'].str.contains("Alley", na = False ) | events_df['HOMEDESCRIPTION'].str.contains("Alley", na = False )  ) ]
    AST_df = AST_df.append(ASTList)
    BadPass_df = BadPass_df.append(BadPassList)
    AlleyOop_df = AlleyOop_df.append(AlleyOopList)
    
AST_df.to_csv("AST_Parsed.csv", sep='\t')
BadPass_df.to_csv("BadPass_Parsed.csv", sep='\t')
AlleyOop_df.to_csv("AlleyOop_Parsed.csv", sep='\t')
# Out:
# C:\Users\jchin\Documents\GitHub\Data Mining Course\DataMining-Project-Folder\JupyterNotebooks
# 0021500003.csv
# 0021500004.csv

# %% [markdown]
# ## AST_df  assists data frame has time and event num of all assists....

# %%
AST_df
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 4    21500003         4             1                   1       1
# 5    21500003         5             1                  46       1
# 6    21500003         6             1                  99       1
# 11   21500003        11             1                  58       1
# 20   21500003        20             1                  63       1
# 33   21500003        32             1                  42       1
# 34   21500003        34             1                 108       1
# 37   21500003        37             1                   3       1
# 40   21500003        41             1                  75       1
# 42   21500003        45             1                  58       1
# 44   21500003        47             1                   1       1
# 51   21500003        55             1                   1       1
# 60   21500003        66             1                  47       1
# 62   21500003        68             1                  80       1
# 85   21500003        97             1                   5       1
# 99   21500003       112             1                   1       1
# 102  21500003       116             1                  42       1
# 120  21500003       137             1                  50       2
# 159  21500003       182             1                   1       2
# 161  21500003       184             1                  43       2
# 180  21500003       204             1                  43       2
# 188  21500003       214             1                  79       2
# 201  21500003       228             1                  42       2
# 205  21500003       233             1                  98       2
# 222  21500003       252             1                   1       2
# 225  21500003       255             1                  98       2
# 251  21500003       283             1                  80       3
# 254  21500003       286             1                  78       3
# 280  21500003       318             1                  79       3
# 293  21500003       333             1                  99       3
# ..        ...       ...           ...                 ...     ...
# 47   21500004        52             1                   5       1
# 65   21500004        71             1                  41       1
# 66   21500004        72             1                  46       1
# 67   21500004        73             1                   1       1
# 72   21500004        78             1                  46       1
# 78   21500004        84             1                   1       1
# 81   21500004        87             1                   1       1
# 82   21500004        89             1                   1       1
# 105  21500004       123             1                   1       1
# 120  21500004       142             1                   1       2
# 128  21500004       150             1                   1       2
# 148  21500004       174             1                  98       2
# 155  21500004       182             1                  41       2
# 169  21500004       198             1                   3       2
# 171  21500004       200             1                  98       2
# 172  21500004       201             1                   1       2
# 190  21500004       219             1                  79       2
# 202  21500004       233             1                  81       2
# 203  21500004       234             1                   1       2
# 205  21500004       236             1                  46       2
# 267  21500004       313             1                   1       3
# 310  21500004       360             1                 103       3
# 321  21500004       375             1                  42       3
# 322  21500004       376             1                  58       3
# 336  21500004       391             1                   1       3
# 371  21500004       432             1                  57       4
# 380  21500004       442             1                  79       4
# 451  21500004       527             1                   3       4
# 458  21500004       534             1                   1       4
# 463  21500004       542             1                  50       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 4       11:03 PM        11:35
# 5       11:03 PM        11:18
# 6       11:04 PM        10:56
# 11      11:04 PM        10:10
# 20      11:06 PM         9:00
# 33      11:08 PM         7:45
# 34      11:08 PM         7:29
# 37      11:09 PM         6:56
# 40      11:10 PM         6:22
# 42      11:13 PM         6:04
# 44      11:14 PM         5:30
# 51      11:15 PM         5:03
# 60      11:17 PM         4:18
# 62      11:18 PM         3:57
# 85      11:25 PM         2:24
# 99      11:27 PM         0:58
# 102     11:28 PM         0:45
# 120     11:35 PM        10:59
# 159     11:43 PM         7:50
# 161     11:44 PM         7:31
# 180     11:47 PM         6:35
# 188     11:51 PM         5:35
# 201     11:53 PM         4:29
# 205     11:54 PM         3:47
# 222     11:59 PM         2:30
# 225     12:00 AM         2:04
# 251     12:22 AM        11:43
# 254     12:22 AM        11:10
# 280     12:30 AM         8:46
# 293     12:32 AM         7:35
# ..           ...          ...
# 47       7:26 PM         6:12
# 65       7:28 PM         4:38
# 66       7:28 PM         4:33
# 67       7:28 PM         4:22
# 72       7:29 PM         3:47
# 78       7:30 PM         3:28
# 81       7:31 PM         2:51
# 82       7:31 PM         2:33
# 105      7:39 PM         0:33
# 120      7:44 PM        11:24
# 128      7:46 PM        10:28
# 148      7:48 PM         9:15
# 155      7:49 PM         8:33
# 169      7:54 PM         7:10
# 171      7:54 PM         6:46
# 172      7:55 PM         6:29
# 190      7:56 PM         5:02
# 202      8:02 PM         3:28
# 203      8:02 PM         3:11
# 205      8:02 PM         2:33
# 267      8:32 PM        10:21
# 310      8:40 PM         6:18
# 321      8:45 PM         4:50
# 322      8:45 PM         4:32
# 336      8:48 PM         3:04
# 371      8:58 PM        11:08
# 380      9:00 PM        10:17
# 451      9:17 PM         3:07
# 458      9:18 PM         2:19
# 463      9:22 PM         2:00
#
#                                        HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 4     Green 26' 3PT Jump Shot (3 PTS) (Thompson 1 AST)                 NaN
# 5                                                  NaN                 NaN
# 6    Curry 3' Cutting Finger Roll Layup Shot (2 PTS...                 NaN
# 11                                                 NaN                 NaN
# 20                                                 NaN                 NaN
# 33                                                 NaN                 NaN
# 34      Bogut  Cutting Dunk Shot (4 PTS) (Curry 1 AST)                 NaN
# 37                                                 NaN                 NaN
# 40   Thompson 1' Driving Finger Roll Layup (2 PTS) ...                 NaN
# 42                                                 NaN                 NaN
# 44                                                 NaN                 NaN
# 51     Curry 29' 3PT Jump Shot (15 PTS) (Barnes 1 AST)                 NaN
# 60   Green 18' Turnaround Jump Shot (5 PTS) (Curry ...                 NaN
# 62   Curry 26' 3PT Step Back Jump Shot (20 PTS) (Gr...                 NaN
# 85                Ezeli  Layup (2 PTS) (Barbosa 1 AST)                 NaN
# 99                                                 NaN                 NaN
# 102   Curry 2' Driving Layup (24 PTS) (Iguodala 1 AST)                 NaN
# 120                                                NaN                 NaN
# 159                                                NaN                 NaN
# 161                                                NaN                 NaN
# 180     Bogut 3' Alley Oop Layup (6 PTS) (Curry 3 AST)                 NaN
# 188  Green 26' 3PT Pullup Jump Shot (8 PTS) (Bogut ...                 NaN
# 201      Barnes 2' Driving Layup (3 PTS) (Curry 4 AST)                 NaN
# 205  Bogut 2' Cutting Layup Shot (8 PTS) (Curry 5 AST)                 NaN
# 222                                                NaN                 NaN
# 225  Bogut 1' Cutting Layup Shot (10 PTS) (Curry 6 ...                 NaN
# 251  Thompson 13' Step Back Jump Shot (6 PTS) (Bogu...                 NaN
# 254  Bogut 8' Floating Jump Shot (12 PTS) (Curry 7 ...                 NaN
# 280  Barnes 16' Pullup Jump Shot (5 PTS) (Bogut 4 AST)                 NaN
# 293  Curry 1' Cutting Finger Roll Layup Shot (37 PT...                 NaN
# ..                                                 ...                 ...
# 47                                                 NaN                 NaN
# 65                                                 NaN                 NaN
# 66   Hezonja 27' 3PT Running Jump Shot (3 PTS) (Pay...                 NaN
# 67                                                 NaN                 NaN
# 72   Hezonja 7' Running Jump Shot (5 PTS) (Payton 2...                 NaN
# 78         Payton 21' Jump Shot (2 PTS) (Gordon 1 AST)                 NaN
# 81       Hezonja  3PT Jump Shot (8 PTS) (Payton 3 AST)                 NaN
# 82                                                 NaN                 NaN
# 105        Watson 18' Jump Shot (2 PTS) (Payton 4 AST)                 NaN
# 120                                                NaN                 NaN
# 128       Payton 19' Jump Shot (6 PTS) (Oladipo 2 AST)                 NaN
# 148  Oladipo 1' Cutting Layup Shot (4 PTS) (Harris ...                 NaN
# 155    Oladipo 2' Running Layup (6 PTS) (Harris 2 AST)                 NaN
# 169                                                NaN                 NaN
# 171                                                NaN                 NaN
# 172         Smith 20' Jump Shot (2 PTS) (Watson 1 AST)                 NaN
# 190                                                NaN                 NaN
# 202  Gordon 5' Pullup Bank Shot (6 PTS) (Payton 5 AST)                 NaN
# 203                                                NaN                 NaN
# 205                                                NaN                 NaN
# 267                                                NaN                 NaN
# 310  Harris 17' Running Pull-Up Jump Shot (11 PTS) ...                 NaN
# 321                                                NaN                 NaN
# 322  Vucevic 4' Turnaround Hook Shot (8 PTS) (Payto...                 NaN
# 336     Oladipo  3PT Jump Shot (11 PTS) (Harris 3 AST)                 NaN
# 371  Dedmon 7' Driving Hook Shot (4 PTS) (Hezonja 1...                 NaN
# 380                                                NaN                 NaN
# 451      Vucevic 8' Hook Shot (10 PTS) (Hezonja 2 AST)                 NaN
# 458  Hezonja 24' 3PT Jump Shot (11 PTS) (Vucevic 2 ...                 NaN
# 463     Harris 1' Running Dunk (15 PTS) (Payton 8 AST)                 NaN
#
#                                     VISITORDESCRIPTION  \
# 4                                                  NaN
# 5    Davis 7' Running Jump Shot (2 PTS) (Gordon 1 AST)
# 6                                                  NaN
# 11   Perkins 11' Turnaround Hook Shot (2 PTS) (Gord...
# 20   Perkins 9' Fadeaway Jumper (4 PTS) (Robinson 1...
# 33   Cunningham 3' Driving Layup (2 PTS) (Perkins 1...
# 34                                                 NaN
# 37          Perkins 6' Hook Shot (6 PTS) (Smith 1 AST)
# 40                                                 NaN
# 42   Perkins 8' Turnaround Hook Shot (8 PTS) (Davis...
# 44   Cunningham 25' 3PT Jump Shot (5 PTS) (Gordon 3...
# 51                                                 NaN
# 60                                                 NaN
# 62                                                 NaN
# 85                                                 NaN
# 99       Smith 26' 3PT Jump Shot (9 PTS) (Davis 2 AST)
# 102                                                NaN
# 120            Gee  Running Dunk (2 PTS) (Smith 2 AST)
# 159     Cunningham 21' Jump Shot (7 PTS) (Smith 3 AST)
# 161  Cunningham 2' Alley Oop Layup (9 PTS) (Smith 4...
# 180                                                NaN
# 188                                                NaN
# 201                                                NaN
# 205                                                NaN
# 222  Cunningham 24' 3PT Jump Shot (13 PTS) (Smith 5...
# 225                                                NaN
# 251                                                NaN
# 254                                                NaN
# 280                                                NaN
# 293                                                NaN
# ..                                                 ...
# 47            Beal 1' Layup (5 PTS) (Porter Jr. 2 AST)
# 65        Beal 1' Running Layup (7 PTS) (Gortat 2 AST)
# 66                                                 NaN
# 67   Gooden 24' 3PT Jump Shot (3 PTS) (Sessions 1 AST)
# 72                                                 NaN
# 78                                                 NaN
# 81                                                 NaN
# 82        Beal 21' Jump Shot (12 PTS) (Sessions 2 AST)
# 105                                                NaN
# 120            Neal 17' Jump Shot (2 PTS) (Nene 1 AST)
# 128                                                NaN
# 148                                                NaN
# 155                                                NaN
# 169           Gortat 3' Hook Shot (4 PTS) (Wall 3 AST)
# 171  Gortat 1' Cutting Layup Shot (6 PTS) (Porter J...
# 172                                                NaN
# 190     Neal 21' Pullup Jump Shot (6 PTS) (Wall 4 AST)
# 202                                                NaN
# 203  Humphries 21' Jump Shot (4 PTS) (Porter Jr. 4 ...
# 205  Humphries  3PT Running Jump Shot (7 PTS) (Wall...
# 267    Gortat 11' Jump Shot (8 PTS) (Porter Jr. 5 AST)
# 310                                                NaN
# 321        Beal 2' Driving Layup (17 PTS) (Wall 6 AST)
# 322                                                NaN
# 336                                                NaN
# 371                                                NaN
# 380  Wall 19' Pullup Jump Shot (12 PTS) (Gooden 1 AST)
# 451                                                NaN
# 458                                                NaN
# 463                                                NaN
#
#                ...             PLAYER2_TEAM_CITY PLAYER2_TEAM_NICKNAME  \
# 4              ...                  Golden State              Warriors
# 5              ...                   New Orleans              Pelicans
# 6              ...                  Golden State              Warriors
# 11             ...                   New Orleans              Pelicans
# 20             ...                   New Orleans              Pelicans
# 33             ...                   New Orleans              Pelicans
# 34             ...                  Golden State              Warriors
# 37             ...                   New Orleans              Pelicans
# 40             ...                  Golden State              Warriors
# 42             ...                   New Orleans              Pelicans
# 44             ...                   New Orleans              Pelicans
# 51             ...                  Golden State              Warriors
# 60             ...                  Golden State              Warriors
# 62             ...                  Golden State              Warriors
# 85             ...                  Golden State              Warriors
# 99             ...                   New Orleans              Pelicans
# 102            ...                  Golden State              Warriors
# 120            ...                   New Orleans              Pelicans
# 159            ...                   New Orleans              Pelicans
# 161            ...                   New Orleans              Pelicans
# 180            ...                  Golden State              Warriors
# 188            ...                  Golden State              Warriors
# 201            ...                  Golden State              Warriors
# 205            ...                  Golden State              Warriors
# 222            ...                   New Orleans              Pelicans
# 225            ...                  Golden State              Warriors
# 251            ...                  Golden State              Warriors
# 254            ...                  Golden State              Warriors
# 280            ...                  Golden State              Warriors
# 293            ...                  Golden State              Warriors
# ..             ...                           ...                   ...
# 47             ...                    Washington               Wizards
# 65             ...                    Washington               Wizards
# 66             ...                       Orlando                 Magic
# 67             ...                    Washington               Wizards
# 72             ...                       Orlando                 Magic
# 78             ...                       Orlando                 Magic
# 81             ...                       Orlando                 Magic
# 82             ...                    Washington               Wizards
# 105            ...                       Orlando                 Magic
# 120            ...                    Washington               Wizards
# 128            ...                       Orlando                 Magic
# 148            ...                       Orlando                 Magic
# 155            ...                       Orlando                 Magic
# 169            ...                    Washington               Wizards
# 171            ...                    Washington               Wizards
# 172            ...                       Orlando                 Magic
# 190            ...                    Washington               Wizards
# 202            ...                       Orlando                 Magic
# 203            ...                    Washington               Wizards
# 205            ...                    Washington               Wizards
# 267            ...                    Washington               Wizards
# 310            ...                       Orlando                 Magic
# 321            ...                    Washington               Wizards
# 322            ...                       Orlando                 Magic
# 336            ...                       Orlando                 Magic
# 371            ...                       Orlando                 Magic
# 380            ...                    Washington               Wizards
# 451            ...                       Orlando                 Magic
# 458            ...                       Orlando                 Magic
# 463            ...                       Orlando                 Magic
#
#      PLAYER2_TEAM_ABBREVIATION  PERSON3TYPE PLAYER3_ID  PLAYER3_NAME  \
# 4                          GSW            0          0           NaN
# 5                          NOP            0          0           NaN
# 6                          GSW            0          0           NaN
# 11                         NOP            0          0           NaN
# 20                         NOP            0          0           NaN
# 33                         NOP            0          0           NaN
# 34                         GSW            0          0           NaN
# 37                         NOP            0          0           NaN
# 40                         GSW            0          0           NaN
# 42                         NOP            0          0           NaN
# 44                         NOP            0          0           NaN
# 51                         GSW            0          0           NaN
# 60                         GSW            0          0           NaN
# 62                         GSW            0          0           NaN
# 85                         GSW            0          0           NaN
# 99                         NOP            0          0           NaN
# 102                        GSW            0          0           NaN
# 120                        NOP            0          0           NaN
# 159                        NOP            0          0           NaN
# 161                        NOP            0          0           NaN
# 180                        GSW            0          0           NaN
# 188                        GSW            0          0           NaN
# 201                        GSW            0          0           NaN
# 205                        GSW            0          0           NaN
# 222                        NOP            0          0           NaN
# 225                        GSW            0          0           NaN
# 251                        GSW            0          0           NaN
# 254                        GSW            0          0           NaN
# 280                        GSW            0          0           NaN
# 293                        GSW            0          0           NaN
# ..                         ...          ...        ...           ...
# 47                         WAS            0          0           NaN
# 65                         WAS            0          0           NaN
# 66                         ORL            0          0           NaN
# 67                         WAS            0          0           NaN
# 72                         ORL            0          0           NaN
# 78                         ORL            0          0           NaN
# 81                         ORL            0          0           NaN
# 82                         WAS            0          0           NaN
# 105                        ORL            0          0           NaN
# 120                        WAS            0          0           NaN
# 128                        ORL            0          0           NaN
# 148                        ORL            0          0           NaN
# 155                        ORL            0          0           NaN
# 169                        WAS            0          0           NaN
# 171                        WAS            0          0           NaN
# 172                        ORL            0          0           NaN
# 190                        WAS            0          0           NaN
# 202                        ORL            0          0           NaN
# 203                        WAS            0          0           NaN
# 205                        WAS            0          0           NaN
# 267                        WAS            0          0           NaN
# 310                        ORL            0          0           NaN
# 321                        WAS            0          0           NaN
# 322                        ORL            0          0           NaN
# 336                        ORL            0          0           NaN
# 371                        ORL            0          0           NaN
# 380                        WAS            0          0           NaN
# 451                        ORL            0          0           NaN
# 458                        ORL            0          0           NaN
# 463                        ORL            0          0           NaN
#
#     PLAYER3_TEAM_ID PLAYER3_TEAM_CITY PLAYER3_TEAM_NICKNAME  \
# 4               NaN               NaN                   NaN
# 5               NaN               NaN                   NaN
# 6               NaN               NaN                   NaN
# 11              NaN               NaN                   NaN
# 20              NaN               NaN                   NaN
# 33              NaN               NaN                   NaN
# 34              NaN               NaN                   NaN
# 37              NaN               NaN                   NaN
# 40              NaN               NaN                   NaN
# 42              NaN               NaN                   NaN
# 44              NaN               NaN                   NaN
# 51              NaN               NaN                   NaN
# 60              NaN               NaN                   NaN
# 62              NaN               NaN                   NaN
# 85              NaN               NaN                   NaN
# 99              NaN               NaN                   NaN
# 102             NaN               NaN                   NaN
# 120             NaN               NaN                   NaN
# 159             NaN               NaN                   NaN
# 161             NaN               NaN                   NaN
# 180             NaN               NaN                   NaN
# 188             NaN               NaN                   NaN
# 201             NaN               NaN                   NaN
# 205             NaN               NaN                   NaN
# 222             NaN               NaN                   NaN
# 225             NaN               NaN                   NaN
# 251             NaN               NaN                   NaN
# 254             NaN               NaN                   NaN
# 280             NaN               NaN                   NaN
# 293             NaN               NaN                   NaN
# ..              ...               ...                   ...
# 47              NaN               NaN                   NaN
# 65              NaN               NaN                   NaN
# 66              NaN               NaN                   NaN
# 67              NaN               NaN                   NaN
# 72              NaN               NaN                   NaN
# 78              NaN               NaN                   NaN
# 81              NaN               NaN                   NaN
# 82              NaN               NaN                   NaN
# 105             NaN               NaN                   NaN
# 120             NaN               NaN                   NaN
# 128             NaN               NaN                   NaN
# 148             NaN               NaN                   NaN
# 155             NaN               NaN                   NaN
# 169             NaN               NaN                   NaN
# 171             NaN               NaN                   NaN
# 172             NaN               NaN                   NaN
# 190             NaN               NaN                   NaN
# 202             NaN               NaN                   NaN
# 203             NaN               NaN                   NaN
# 205             NaN               NaN                   NaN
# 267             NaN               NaN                   NaN
# 310             NaN               NaN                   NaN
# 321             NaN               NaN                   NaN
# 322             NaN               NaN                   NaN
# 336             NaN               NaN                   NaN
# 371             NaN               NaN                   NaN
# 380             NaN               NaN                   NaN
# 451             NaN               NaN                   NaN
# 458             NaN               NaN                   NaN
# 463             NaN               NaN                   NaN
#
#      PLAYER3_TEAM_ABBREVIATION
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 11                         NaN
# 20                         NaN
# 33                         NaN
# 34                         NaN
# 37                         NaN
# 40                         NaN
# 42                         NaN
# 44                         NaN
# 51                         NaN
# 60                         NaN
# 62                         NaN
# 85                         NaN
# 99                         NaN
# 102                        NaN
# 120                        NaN
# 159                        NaN
# 161                        NaN
# 180                        NaN
# 188                        NaN
# 201                        NaN
# 205                        NaN
# 222                        NaN
# 225                        NaN
# 251                        NaN
# 254                        NaN
# 280                        NaN
# 293                        NaN
# ..                         ...
# 47                         NaN
# 65                         NaN
# 66                         NaN
# 67                         NaN
# 72                         NaN
# 78                         NaN
# 81                         NaN
# 82                         NaN
# 105                        NaN
# 120                        NaN
# 128                        NaN
# 148                        NaN
# 155                        NaN
# 169                        NaN
# 171                        NaN
# 172                        NaN
# 190                        NaN
# 202                        NaN
# 203                        NaN
# 205                        NaN
# 267                        NaN
# 310                        NaN
# 321                        NaN
# 322                        NaN
# 336                        NaN
# 371                        NaN
# 380                        NaN
# 451                        NaN
# 458                        NaN
# 463                        NaN
#
# [87 rows x 33 columns]

# %%
# for each assist event ....

CleanData_df = pd.DataFrame()
curPath = os.getcwd()
print curPath
SportVU_JSON_Rootpath = "D:\\DataMining-NBA-Repo\\JupyterNotebooks\\SportVU_JSON_Data\\"
#print SportVU_JSON_Rootpath+str(gameid)+".json"
gameid_prev = 0;
for index, ast in AST_df.iterrows():
    gameid = ast["GAME_ID"]    #game id from PBP
    eventNumPBP = ast["EVENTNUM"] #eventNumber for the play
    gametimePBP = ast["PCTIMESTRING"]  #game time for the play
    quarterPBP = int(ast["PERIOD"])
    print("prevGameID:"+str(gameid_prev)+", currentlyAnalyzingGameID:"+str(gameid))
    print("PBPEventNum:"+str(eventNumPBP)+", gametimePBP:"+str(gametimePBP))
    #check if SportVU json data is already opened for this PBP play
    if(gameid_prev != gameid):
        #open raw JSON SportVU data using game id from assist
        with open(SportVU_JSON_Rootpath+"00"+str(gameid)+".json") as data_file:    
            rawSportVUData = json.load(data_file)
            json_normalize(rawSportVUData['events'])
        gameid_prev = gameid
    
    #get the correct eventNum (returned as long) in SportsVU
    eventNumSportsVU = findCorrectMomentData(rawSportVUData, quarterPBP, gametimePBP, eventNumPBP)
    
    #extract SportsVU movements for that eventNum
    rawpossessionSportsVU = MomentsfromEventNum(rawSportVUData, int(eventNumSportsVU))
    
    #for analyzing AST only...
    receiverID = int(ast['PLAYER1_ID'])
    passerID = int(ast['PLAYER2_ID'])
    teamID = int(ast['PLAYER1_TEAM_ID'])
                     
    #get catch details (who was the passer, receiver, and when caught/passed)
    timeBallReleased, indexBallReleased, timeBallCaught, indexBallCaught, timeBallPassed, indexBallPassed, receiverPosAtPass, receiverPosAtCaught, passerPosAtPass= getCatchEventDetails(receiverID, passerID, gametimePBP, rawpossessionSportsVU)
    
    #hull details
    hull, np_points = getHull(rawpossessionSportsVU, teamID)
                     
    #passer in hull?
    
    passerInHull = isInHull(hull,np_points, passerPosAtPass[0] ,passerPosAtPass[1])
                     
    #receiver in hull?
    receiverInHull = isInHull(hull,np_points, receiverPosAtPass[0] ,receiverPosAtPass[1])
    
    #CleanData_df
    
Cleandata_df.to_csv("CleanedData.csv", sep='\t')
# Out:
#   File "<ipython-input-16-ceffa473430e>", line 33
#     teamID = int(ast['PLAYER1_TEAM_ID])
#                                       ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ## Loop through queried events
# ## Extract EventNum from Movement dataset
# ## Save to new dataframe
# ## Append event's specific column to this dataframe row

# %%
#for i, row in events_queried.iterrows():
for i in range(events_queried.shape[0]):
    #extract the row from events dataframe
    extractedRow = events_queried.iloc[i]
    print extractedRow
    #movement_events_df.append(extractedRow,ignore_index=True)
    movement_events_df = movement_events_df.append(pd.DataFrame(extractedRow), ignore_index=True)
    #movement_events_df = pd.concat([movement_events_df, row], axis=1)
