# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## Read one game's moments and events dataset

# %%
moments_df = pd.read_json("0021500492.json")

# %%
events_df = pd.read_csv('0021500492.csv')

# %% [markdown]
# ## Filter event with STLS or etc...
# Step-by-step explanation (from inner to outer):
#
# df['ids'] selects the ids column of the data frame (techincally, the object df[ids] is of type pandas.Series)
#
# df['ids'].str allows us to apply vectorized string methods (e.g., lower, contains) to the Series
#
# df['ids'].str.contains('ball') checks each element of the Series as to whether the element value has the string 'ball' as a substring. The result is a Series of Booleans indicating True or False about the existence of a 'ball' substring.
#
# df[df['ids'].str.contains('ball')] applies the Boolean 'mask' to the dataframe and returns a view containing appropriate records.
#
# na = False removes NA / NaN values from consideration; otherwise a ValueError may be returned.
#
# ### This returns all events/possessions of when the queried event occured

# %%
events_queried = events_df[events_df['HOMEDESCRIPTION'].str.contains("REBOUND", na = False )]

# %%
events_queried
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 3    21500492         3             4                   0       1
# 13   21500492        17             4                   0       1
# 15   21500492        19             4                   0       1
# 17   21500492        21             4                   0       1
# 23   21500492        27             4                   0       1
# 28   21500492        32             4                   0       1
# 38   21500492        45             4                   0       1
# 43   21500492        50             4                   0       1
# 69   21500492        80             4                   0       1
# 79   21500492        92             4                   0       1
# 102  21500492       120             4                   0       1
# 120  21500492       139             4                   0       2
# 137  21500492       163             4                   0       2
# ...

# %% [markdown]
# ## Create dataframe for movement data appended with events

# %%
movement_events_df = pd.DataFrame()

# %% [markdown]
# ## Loop through queried events
# ## Extract EventNum from Movement dataset
# ## Save to new dataframe
# ## Append event's specific column to this dataframe row

# %%
#for i, row in events_queried.iterrows():
for i in range(events_queried.shape[0]):
    #extract the row from events dataframe
    extractedRow = events_queried.iloc[i]
    print extractedRow
    #movement_events_df.append(extractedRow,ignore_index=True)
    movement_events_df = movement_events_df.append(pd.DataFrame(extractedRow), ignore_index=True)
    #movement_events_df = pd.concat([movement_events_df, row], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4376feb5150b> in <module>()
#       5     #print extractedRow
#       6     #movement_events_df.append(extractedRow,ignore_index=True)
# ----> 7     movement_events_df = movement_events_df.append((row), ignore_index=True)
#       8     #movement_events_df = movement_events_df.append(pd.DataFrame(extractedRow), ignore_index=True)
#       9     #movement_events_df = pd.concat([movement_events_df, row], axis=1)
#
# C:\Users\jchin\Anaconda2\lib\site-packages\pandas\core\frame.pyc in append(self, other, ignore_index, verify_integrity)
#    4639         from pandas.core.reshape.concat import concat
#    4640         if isinstance(other, (list, tuple)):
# -> 4641             to_concat = [self] + other
#    4642         else:
#    4643             to_concat = [self, other]
#
# ...

# %%
events_queried.shape[0]
# Out:
# 54

# %%
movement_events_df.shape[0]
# Out:
# 1782

# %%
movement_events_df
# Out:
#                                     3    13   15   17   23   28   38   43   \
# 0                              21500492  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                                     3  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                                     4  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                                     0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                                     1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5                               7:42 PM  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6                                 11:39  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7     Valanciunas REBOUND (Off:1 Def:0)  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9                                   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10                                  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...
